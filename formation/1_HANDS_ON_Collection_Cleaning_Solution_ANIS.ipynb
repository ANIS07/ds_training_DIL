# %% [markdown]
# # <center>Data Science Training - AXA Data Innovation Lab - Hands-on</center>
# <center><b>Hands-on sessions</b><br>
# Nathaniel Bern, June 2016</center>

# %% [markdown]
# # Goals and objectives <font color='blue'> (10 min) </font>

# %% [markdown]
# The series of IPython notebooks will guide you through the study of NYC Bikes Data, from data collection and cleaning to visualization, feature engineering and modelling.
#
# We will be predicting whether a trip was made by a customer or a subscriber, thanks to different machine learning algorithms.
#
# There will be **4 IPython notebooks**, for each step :
# 1. Data collection and cleaning
# 2. Visualization
# 3. Feature engineering
# 4. Data modeling

# %% [markdown]
# ### <font color='red'>Steps that you will need to complete will be written in red </font>
# ### <font color='blue'>The time that you will be given will be written in blue </font>

# %% [markdown]
# # Data collection and cleaning

# %% [markdown]
# Data has been downloaded from https://www.citibikenyc.com/system-data and has been open-sourced by *City Bike*.
#
# The dataset consists in all bike trips in NYC that happened in June 2015, with the following information:
# - Trip Duration (seconds)
# - Start Time and Date
# - Stop Time and Date
# - Start Station Name
# - End Station Name
# - Station ID
# - Station Lat/Long
# - Bike ID
# - User Type (Customer = 24-hour pass or 7-day pass user; Subscriber = Annual Member)
# - Gender (Zero=unknown; 1=male; 2=female)
# - Year of Birth
#
# The **pandas** package will be used all throughout the notebooks to load data and easily perform data analysis.
#
# ## Steps
# - Core dataset collection
# - Weather and temperature enrichment
# - Number of docks per station enrichment

# %% [markdown]
# # Google doc with code corrections is accessible at:
# ### https://docs.google.com/document/d/1q63UIVenEinpAlK_bzt4paao_g4a0xQEMQLwX0qfHyE/edit?usp=sharing

# %% [markdown]
# # Necessary packages to study this dataset
#
# If you are running these notebooks from your own computer, you will be required to have the following packages installed:
#
# - **Basic packages** from Anaconda such as *numpy*, *pandas*, *scikit-learn*, ...
# - seaborn
# - Basemap
# - haversine
# - networkx
# - folium
# - urllib2

# %% [markdown]
# # 0) Using IPython notebook: tricks and tips <font color='blue'> (10 min) </font>

# %% [markdown]
# An IPython notebook is made of different boxes (or lines), which can be run independently from one another. They can be filled either with *Python code*, or with **Markdown code** as in this box.
#
# - Click on the <b>LEFT SIDE</b> of a box, and press **A** to create a box **Above**, and **B** to create a box **Below**
# - Click on the <b>LEFT SIDE</b> of a box, and double-press **D** to delete it
# - Click on the <b>LEFT SIDE</b> of a box, and press **X** to cut it, and **V** to paste it
# - Press **Shift + Enter** to run a box and go to the next one
#
# By default, boxes will accept Python code. To create a **Markdown** box, click on the left side of the box, press **m** for **mardown**, and then you will be able to fill your box with the markdown format. For instance, if you write ### Title 1 in a **markdown defined box**, and then press **Shift + Enter** to run it.

# %% [markdown]
# ### <font color='red'>0.1) Run the following lines by pressing Shift + Enter</font>

# %%
print 'Hello World'
# Out:
# Hello World

# %%
user_name = "Data Scientist"  # Enter you name between the quotation marks
user_age = 34  # Enter your age here

print 'Hello, my name is {}'.format(user_name)
print 'I am {} years old'.format(user_age)
# Out:
# Hello, my name is Data Scientist
# I am 34 years old

# %% [markdown]
# ### <font color='red'>0.2) Create a Markdown cell by:</font>
# - clicking on the left side of the cell
# - typing m
# - entering in the cell the following text (include the sharp signs): *### This is a Markdown cell*
# - running the cell with **Maj + Enter**

# %% [markdown]
# ### <font color='red'>0.3) Add/Delete cells by clicking on the left side of a cell, and pressing "a" (above), "b" (below) and "dd" (delete)</font>

# %% [markdown]
# ### Importing the necessary packages
#
# Packages are imported at the beginning of the file, and can be aliased. For instance, the **pandas** package can be aliased as **pd**, the **numpy** package as **np**, and all **pandas** functions will be called with **pd.function** instead of **pandas.function**

# %%
from __future__ import division  # This allows for float division

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /Users/axa/.pyenv/versions/2.7.12/envs/DS/lib/python2.7/site-packages/IPython/html.py:14: ShimWarning: The `IPython.html` package has been deprecated. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)

# %% [markdown]
# <b>TIP</b>: You can press <b>TAB</b> for getting auto-completion of a command

# %% [markdown]
# ### <font color='red'> 0.4) Start typing the user_name variable ('user_name') and press TAB to get auto-completion. Choose the right variable by pressing ENTER </font>

# %%
#### TYPE user.... + TAB and choose the right variable by pressing ENTER ####

# %% [markdown]
# ### <font color='red'>0.5) Import the pandas package and give it the alias <i>pd</i></font>

# %%
import pandas as pd

# %% [markdown]
# ### <font color='red'>0.6) Get help on a module by calling the <i>help()</i> function with the aliased module as the parameter</font>

# %% [markdown]
# ### <font color='red'>0.7) Get help on module functions by calling the <i>help()</i> function on them</font>

# %%
help(sns.pointplot)
# Out:
# Help on function pointplot in module seaborn.categorical:
#
# pointplot(x=None, y=None, hue=None, data=None, order=None, hue_order=None, estimator=<function mean>, ci=95, n_boot=1000, units=None, markers='o', linestyles='-', dodge=False, join=True, scale=1, orient=None, color=None, palette=None, ax=None, errwidth=None, capsize=None, **kwargs)
#     Show point estimates and confidence intervals using scatter plot glyphs.
#
#     A point plot represents an estimate of central tendency for a numeric
#     variable by the position of scatter plot points and provides some
#     indication of the uncertainty around that estimate using error bars.
#
#     Point plots can be more useful than bar plots for focusing comparisons
#     between different levels of one or more categorical variables. They are
#     particularly adept at showing interactions: how the relationship between
#     levels of one categorical variable changes across levels of a second
#     categorical variable. The lines that join each point from the same ``hue``
#     level allow interactions to be judged by differences in slope, which is
#     easier for the eyes than comparing the heights of several groups of points
#     or bars.
#
#     It is important to keep in mind that a point plot shows only the mean (or
#     other estimator) value, but in many cases it may be more informative to
#     show the distribution of values at each level of the categorical variables.
#     In that case, other approaches such as a box or violin plot may be more
#     appropriate.
#
#     Input data can be passed in a variety of formats, including:
#
#     - Vectors of data represented as lists, numpy arrays, or pandas Series
#       objects passed directly to the ``x``, ``y``, and/or ``hue`` parameters.
#     - A "long-form" DataFrame, in which case the ``x``, ``y``, and ``hue``
#       variables will determine how the data are plotted.
#     - A "wide-form" DataFrame, such that each numeric column will be plotted.
#     - Anything accepted by ``plt.boxplot`` (e.g. a 2d array or list of vectors)
#
#     In most cases, it is possible to use numpy or Python objects, but pandas
#     objects are preferable because the associated names will be used to
#     annotate the axes. Additionally, you can use Categorical types for the
#     grouping variables to control the order of plot elements.
#
#     Parameters
#     ----------
#     x, y, hue : names of variables in ``data`` or vector data, optional
#         Inputs for plotting long-form data. See examples for interpretation.
#     data : DataFrame, array, or list of arrays, optional
#         Dataset for plotting. If ``x`` and ``y`` are absent, this is
#         interpreted as wide-form. Otherwise it is expected to be long-form.
#     order, hue_order : lists of strings, optional
#         Order to plot the categorical levels in, otherwise the levels are
#         inferred from the data objects.
#     estimator : callable that maps vector -> scalar, optional
#         Statistical function to estimate within each categorical bin.
#     ci : float or None, optional
#         Size of confidence intervals to draw around estimated values. If
#         ``None``, no bootstrapping will be performed, and error bars will
#         not be drawn.
#     n_boot : int, optional
#         Number of bootstrap iterations to use when computing confidence
#         intervals.
#     units : name of variable in ``data`` or vector data, optional
#         Identifier of sampling units, which will be used to perform a
#         multilevel bootstrap and account for repeated measures design.
#     markers : string or list of strings, optional
#         Markers to use for each of the ``hue`` levels.
#     linestyles : string or list of strings, optional
#         Line styles to use for each of the ``hue`` levels.
#     dodge : bool or float, optional
#         Amount to separate the points for each level of the ``hue`` variable
#         along the categorical axis.
#     join : bool, optional
#         If ``True``, lines will be drawn between point estimates at the same
#         ``hue`` level.
#     scale : float, optional
#         Scale factor for the plot elements.
#     orient : "v" | "h", optional
#         Orientation of the plot (vertical or horizontal). This is usually
#         inferred from the dtype of the input variables, but can be used to
#         specify when the "categorical" variable is a numeric or when plotting
#         wide-form data.
#     color : matplotlib color, optional
#         Color for all of the elements, or seed for :func:`light_palette` when
#         using hue nesting.
#     palette : seaborn color palette or dict, optional
#         Colors to use for the different levels of the ``hue`` variable. Should
#         be something that can be interpreted by :func:`color_palette`, or a
#         dictionary mapping hue levels to matplotlib colors.
#     ax : matplotlib Axes, optional
#         Axes object to draw the plot onto, otherwise uses the current Axes.
#
#     Returns
#     -------
#     ax : matplotlib Axes
#         Returns the Axes object with the boxplot drawn onto it.
#
#     See Also
#     --------
#     barplot : Show point estimates and confidence intervals using bars.
#     factorplot : Combine categorical plots and a class:`FacetGrid`.
#
#     Examples
#     --------
#
#     Draw a set of vertical point plots grouped by a categorical variable:
#
#     .. plot::
#         :context: close-figs
#
#         >>> import seaborn as sns
#         >>> sns.set_style("darkgrid")
#         >>> tips = sns.load_dataset("tips")
#         >>> ax = sns.pointplot(x="time", y="total_bill", data=tips)
#
#     Draw a set of vertical points with nested grouping by a two variables:
#
#     .. plot::
#         :context: close-figs
#
#         >>> ax = sns.pointplot(x="time", y="total_bill", hue="smoker",
#         ...                    data=tips)
#
#     Separate the points for different hue levels along the categorical axis:
#
#     .. plot::
#         :context: close-figs
#
#         >>> ax = sns.pointplot(x="time", y="total_bill", hue="smoker",
#         ...                    data=tips, dodge=True)
#
#     Use a different marker and line style for the hue levels:
#
#     .. plot::
#         :context: close-figs
#
#         >>> ax = sns.pointplot(x="time", y="total_bill", hue="smoker",
#         ...                    data=tips,
#         ...                    markers=["o", "x"],
#         ...                    linestyles=["-", "--"])
#
#     Draw a set of horizontal points:
#
#     .. plot::
#         :context: close-figs
#
#         >>> ax = sns.pointplot(x="tip", y="day", data=tips)
#
#     Don't draw a line connecting each point:
#
#     .. plot::
#         :context: close-figs
#
#         >>> ax = sns.pointplot(x="tip", y="day", data=tips, join=False)
#
#     Use a different color for a single-layer plot:
#
#     .. plot::
#         :context: close-figs
#
#         >>> ax = sns.pointplot("time", y="total_bill", data=tips,
#         ...                    color="#bb3f3f")
#
#     Use a different color palette for the points:
#
#     .. plot::
#         :context: close-figs
#
#         >>> ax = sns.pointplot(x="time", y="total_bill", hue="smoker",
#         ...                    data=tips, palette="Set2")
#
#     Control point order by passing an explicit order:
#
#     .. plot::
#         :context: close-figs
#
#         >>> ax = sns.pointplot(x="time", y="tip", data=tips,
#         ...                    order=["Dinner", "Lunch"])
#
#     Use median as the estimate of central tendency:
#
#     .. plot::
#         :context: close-figs
#
#         >>> from numpy import median
#         >>> ax = sns.pointplot(x="day", y="tip", data=tips, estimator=median)
#
#     Show the standard error of the mean with the error bars:
#
#     .. plot::
#         :context: close-figs
#
#         >>> ax = sns.pointplot(x="day", y="tip", data=tips, ci=68)
#
#     Add "caps" to the error bars:
#
#     .. plot::
#         :context: close-figs
#
#         >>> ax = sns.pointplot(x="day", y="tip", data=tips, capsize=.2)

# %% [markdown]
# ## 1) Core dataset collection <font color='blue'> (30 min) </font>

# %% [markdown]
# ### <font color='red'>1.1) Load data by using the <i>read_csv</i> function of pandas (which has been aliased as pd) ; data is located in <i>'../data/raw_data.csv'</i></font>

# %%
orig_data = pd.read_csv('./201506-citibike-tripdata.csv')

# %% [markdown]
# ### <font color='red'>Run the following line so data is copied and does not need to be reloaded in case of mistakes</font>

# %%
data = orig_data.copy()

# %% [markdown]
# ### <font color='red'>1.2) Show a sample (or several samples) of data by calling the method <i>.sample()</i> on the <i>data</i> dataframe</font>

# %%
data.sample(3)
# Out:
#         tripduration        starttime         stoptime  start station id  \
# 159605           813   6/7/2015 12:06   6/7/2015 12:20               448
# 610423          2016  6/20/2015 19:47  6/20/2015 20:20               387
# 450276           398   6/16/2015 7:41   6/16/2015 7:47               484
#
#              start station name  start station latitude  \
# 159605         W 37 St & 10 Ave               40.756604
# 610423  Centre St & Chambers St               40.712733
# 450276          W 44 St & 5 Ave               40.755003
#
#         start station longitude  end station id    end station name  \
# 159605               -73.997901             486  Broadway & W 29 St
# 610423               -74.004607             217       Old Fulton St
# 450276               -73.980144             468  Broadway & W 55 St
#
#         end station latitude  end station longitude  bikeid    usertype  \
# 159605             40.746201             -73.988557   19072  Subscriber
# 610423             40.702772             -73.993836   22079    Customer
# 450276             40.765265             -73.981923   17430  Subscriber
#
#         birth year  gender
# 159605      1976.0       1
# 610423         NaN       0
# 450276      1976.0       1

# %% [markdown]
# ### <font color='red'>1.3) Describe your data by calling the function <i>.describe()</i> on the <i>data</i> dataframe</font>

# %%
data.describe()
# Out:
#        tripduration  start station id  start station latitude  \
# count  9.412190e+05     941219.000000           941219.000000
# mean   9.046028e+02        459.987285               40.734750
# std    3.446744e+03        384.455415                0.019363
# min    6.000000e+01         72.000000               40.680342
# 25%    4.010000e+02        306.000000               40.721101
# 50%    6.460000e+02        415.000000               40.736494
# 75%    1.064000e+03        492.000000               40.750200
# max    1.691873e+06       3002.000000               40.771522
#
#        start station longitude  end station id  end station latitude  \
# count            941219.000000   941219.000000         941219.000000
# mean                -73.991312      458.256856             40.734420
# std                   0.012420      383.179189              0.019332
# min                 -74.017134       72.000000             40.680342
# 25%                 -74.001497      305.000000             40.720828
# 50%                 -73.990985      411.000000             40.736245
# 75%                 -73.982050      490.000000             40.749156
# max                 -73.950048     3002.000000             40.771522
#
#        end station longitude         bikeid     birth year         gender
# count          941219.000000  941219.000000  810827.000000  941219.000000
# mean              -73.991443   18174.511302    1976.256380       1.061284
# std                 0.012430    2113.307306      11.465324       0.579512
# min               -74.017134   14529.000000    1885.000000       0.000000
# 25%               -74.001547   16370.000000    1968.000000       1.000000
# 50%               -73.990985   18158.000000    1979.000000       1.000000
# 75%               -73.982050   19944.000000    1985.000000       1.000000
# max               -73.950048   22364.000000    1999.000000       2.000000

# %% [markdown]
# ### <font color='red'>1.4) Print a column using <i>data.column_name</i> or <i>data[column_name]</i></font>

# %%
data.columns
# Out:
# Index([u'tripduration', u'starttime', u'stoptime', u'start station id',
#        u'start station name', u'start station latitude',
#        u'start station longitude', u'end station id', u'end station name',
#        u'end station latitude', u'end station longitude', u'bikeid',
#        u'usertype', u'birth year', u'gender'],
#       dtype='object')

# %% [markdown]
# ### Filtering

# %% [markdown]
# Filters are important in every dataset : data is noisy and filters are meant to keep data clean and understandable, on which models can be trained.
# In Python, slicing conditions for dataframes can be expressed for instance as :
# - **slice_condition = data.gender == 1**
#
# Data can then be sliced with the following :
# - **filtered_data = data[slice_condition]**

# %% [markdown]
# ### <font color='red'>1.5) Get rid of trips that are more than 1.5 hours long (watch out for variable units !)</font>

# %%
# data in second
conv = 0.000277778
data.tripduration_hour = data.tripduration * conv
data = data[data.tripduration_hour<=1.5]

# %% [markdown]
# ### <font color='red'>1.6) Describe a few columns within the dataset using the following functions on the columns:</font>
# - len()
# - .column_name.unique()
# - .column_name.mean()
# - .column_name.median()

# %%
len(data)
# Out:
# 935635

# %%
len(orig_data)
# Out:
# 941219

# %% [markdown]
# ### Changing datetime to datetime format

# %% [markdown]
# ### <font color='red'>1.7) The following block uses the <i>pd.to_datetime()</i> function with the <i>format</i> keyword to create datetime objects from strings columns, for starttime and stoptime.</font><br>
#
# <font color='red'>Look at the string format of <i>starttime</i> and <i>stoptime</i> columns in the initial dataset, and notice how the <i>format</i> attribute matches exactly the structure of the string that you observe on the raw columns.

# %%
#### WHAT IS THE FORMAT OF starttime AND stoptime COLUMNS IN THE INITIAL DATASET ? ####

# %%
data['starttime_formatted'] =  pd.to_datetime(data['starttime'], format="%m/%d/%Y %H:%M")
data['stoptime_formatted'] =  pd.to_datetime(data['stoptime'], format="%m/%d/%Y %H:%M")

# %% [markdown]
# ### <font color='red'>Run the following block to overwrite the starttime and stoptime columns (WARNING: THIS WILL OVERWRITE THE INITIAL COLUMNS)</font>

# %%
data['starttime'] =  data['starttime_formatted']
data['stoptime'] =  data['stoptime_formatted']
del data['starttime_formatted']
del data['stoptime_formatted']

# %% [markdown]
# ### <font color='red'>1.8) Show a sample of 5 observations and check that the new columns have been created</font>

# %%
data.sample(2)
# Out:
#         tripduration           starttime            stoptime  \
# 871542           310 2015-06-29 08:46:00 2015-06-29 08:51:00
# 377344           928 2015-06-13 14:31:00 2015-06-13 14:47:00
#
#         start station id          start station name  start station latitude  \
# 871542               383  Greenwich Ave & Charles St               40.735238
# 377344               147    Greenwich St & Warren St               40.715422
#
#         start station longitude  end station id         end station name  \
# 871542               -74.000271             236      St Marks Pl & 2 Ave
# 377344               -74.011220             225  W 14 St & The High Line
#
#         end station latitude  end station longitude  bikeid    usertype  \
# 871542             40.728419              -73.98714   19870  Subscriber
# 377344             40.741951              -74.00803   20082  Subscriber
#
#         birth year  gender
# 871542      1985.0       1
# 377344      1998.0       1

# %% [markdown]
# ### Fill missing values for birth year : these are called NaN (Not A Number)

# %%
data[data['birth year'].isnull()].sample(3)
# Out:
#         tripduration           starttime            stoptime  \
# 677856           571 2015-06-23 02:30:00 2015-06-23 02:39:00
# 210972          1518 2015-06-08 19:07:00 2015-06-08 19:32:00
# 777116           930 2015-06-25 17:40:00 2015-06-25 17:55:00
#
#         start station id       start station name  start station latitude  \
# 677856               312  Allen St & E Houston St               40.722055
# 210972                72         W 52 St & 11 Ave               40.767272
# 777116               267       Broadway & W 36 St               40.750977
#
#         start station longitude  end station id  \
# 677856               -73.989111             401
# 210972               -73.993929             405
# 777116               -73.987654            2012
#
#                      end station name  end station latitude  \
# 677856        Allen St & Rivington St             40.720196
# 210972  Washington St & Gansevoort St             40.739323
# 777116                E 27 St & 1 Ave             40.739445
#
#         end station longitude  bikeid  usertype  birth year  gender
# 677856             -73.989978   16646  Customer         NaN       0
# 210972             -74.008119   17450  Customer         NaN       0
# 777116             -73.976806   14610  Customer         NaN       0

# %% [markdown]
# ### <font color='red'>1.9) Print the proportion of missing birth years, using:</font>
# - data["column_name"].isnull()
# - data["column_name"].sum()
# - len()

# %%
data.isnull().sum()
# Out:
# tripduration                    0
# starttime                       0
# stoptime                        0
# start station id                0
# start station name              0
# start station latitude          0
# start station longitude         0
# end station id                  0
# end station name                0
# end station latitude            0
# end station longitude           0
# bikeid                          0
# usertype                        0
# birth year                 126090
# gender                          0
# dtype: int64

# %% [markdown]
# ### <font color='red'>1.10) Print the median birth year</font>

# %%
meadian_year = data['birth year'].quantile(0.5)
print 'median year of bith :{}'.format(meadian_year)
# Out:
# median year of bith :1979.0

# %% [markdown]
# ### <font color='red'>1.11) Replace the missing birth years with the median birth year, using the <i>data[column].fillna function</i></font>

# %%
data['birth year'] = data['birth year'].fillna(meadian_year)

# %% [markdown]
# ## 2) Enrich dataset with hourly weather and temperature from weather websites <font color='blue'> (40 min) </font>

# %% [markdown]
# We can get historical New York City weather at :
# http://www.wunderground.com/history/

# %% [markdown]
# ### <font color='red'>2.1) Go to the website, and check for weather and temperature in New York City on a random day in June 2015</font>

# %% [markdown]
# ### <font color='red'>2.2) Run the following block so as to import the right packages</font>

# %%
import urllib2
import json
import re

# %% [markdown]
# ### <font color='red'>2.3) Use the <i>urllib2.urlopen</i> function to open the following webpage:</font>
# http://www.wunderground.com/history/airport/KNYC/2015/6/1/DailyHistory.html?req_city=New%20York&req_state=NY&req_statename=New%20York&reqdb.zip=10001&reqdb.magic=5&reqdb.wmo=99999&format=1

# %%
lync = 'http://www.wunderground.com/history/airport/KNYC/2015/6/1/DailyHistory.html?req_city=New%20York&req_state=NY&req_statename=New%20York&reqdb.zip=10001&reqdb.magic=5&reqdb.wmo=99999&format=1'

# %%
response =  urllib2.urlopen(lync)

# %% [markdown]
# ### <font color='red'>2.3) Read the response with the <i>.read()</i> function</font>

# %%
html = response.read()

# %% [markdown]
# ### <font color='red'>2.4) Print the html response here </font>

# %%
print html
# Out:
# TimeEDT,TemperatureC,Dew PointC,Humidity,Sea Level PressurehPa,VisibilityKm,Wind Direction,Wind SpeedKm/h,Gust SpeedKm/h,Precipitationmm,Events,Conditions,WindDirDegrees,DateUTC<br />
# 12:51 AM,13.9,12.2,89,1019.8,12.9,East,16.7,37.0,0.00,,Overcast,80,2015-06-01 04:51:00<br />
# 1:51 AM,13.9,12.2,89,1019.4,16.1,East,16.7,29.6,N/A,,Overcast,90,2015-06-01 05:51:00<br />
# 2:51 AM,13.9,12.2,89,1019.2,11.3,ENE,14.8,-,0.00,Rain,Light Rain,60,2015-06-01 06:51:00<br />
# 3:20 AM,14.4,12.8,90,1019.9,2.8,ENE,13.0,-,0.04,Rain,Heavy Rain,70,2015-06-01 07:20:00<br />
# 3:34 AM,13.9,12.8,93,1019.9,4.8,ENE,11.1,-,0.21,Rain,Light Rain,60,2015-06-01 07:34:00<br />
# 3:51 AM,13.9,12.2,89,1019.3,8.0,ENE,7.4,-,0.23,Rain,Rain,70,2015-06-01 07:51:00<br />
# 3:59 AM,13.9,12.8,93,1020.2,2.8,Variable,7.4,-,0.04,Rain,Heavy Rain,0,2015-06-01 07:59:00<br />
# 4:08 AM,13.9,12.2,89,1019.9,3.2,ENE,13.0,-,0.12,Rain,Rain,60,2015-06-01 08:08:00<br />
# 4:11 AM,13.9,12.2,89,1019.9,4.8,ENE,16.7,27.8,0.12,Rain,Rain,70,2015-06-01 08:11:00<br />
# 4:51 AM,13.9,12.2,89,1018.9,9.7,Variable,9.3,-,0.16,Rain,Light Rain,0,2015-06-01 08:51:00<br />
# 5:51 AM,13.9,12.2,89,1019.0,16.1,ENE,11.1,-,0.03,,Overcast,60,2015-06-01 09:51:00<br />
# 6:51 AM,13.3,12.2,93,1019.8,8.0,Variable,7.4,-,0.00,Rain,Light Rain,0,2015-06-01 10:51:00<br />
# 7:51 AM,13.3,12.2,93,1020.3,4.0,ENE,13.0,-,0.01,,Overcast,60,2015-06-01 11:51:00<br />
# 7:58 AM,13.3,12.2,93,1021.2,3.2,ENE,16.7,27.8,N/A,,Overcast,60,2015-06-01 11:58:00<br />
# 8:21 AM,13.3,11.7,90,1020.9,4.8,ENE,14.8,27.8,0.00,,Overcast,70,2015-06-01 12:21:00<br />
# 8:51 AM,13.3,11.7,90,1020.0,8.0,ENE,14.8,25.9,0.00,,Overcast,60,2015-06-01 12:51:00<br />
# 9:51 AM,13.3,11.7,90,1020.0,4.8,ENE,13.0,-,N/A,,Overcast,70,2015-06-01 13:51:00<br />
# 10:29 AM,13.3,11.7,90,1020.9,4.0,ENE,22.2,31.5,0.00,Rain,Light Rain,60,2015-06-01 14:29:00<br />
# 10:51 AM,13.3,11.7,90,1020.2,2.4,ENE,18.5,27.8,0.03,Rain,Rain,60,2015-06-01 14:51:00<br />
# 11:10 AM,12.8,11.7,93,1020.9,3.2,East,16.7,33.3,0.06,Rain,Rain,80,2015-06-01 15:10:00<br />
# 11:19 AM,12.8,11.1,89,1020.9,2.4,ENE,18.5,29.6,0.09,Rain,Heavy Rain,60,2015-06-01 15:19:00<br />
# 11:32 AM,13.3,11.7,90,1020.9,4.0,ENE,16.7,27.8,0.13,Rain,Rain,60,2015-06-01 15:32:00<br />
# 11:51 AM,13.3,11.7,90,1020.2,9.7,ENE,16.7,27.8,0.16,Rain,Light Rain,70,2015-06-01 15:51:00<br />
# 12:51 PM,13.3,11.7,90,1019.9,4.8,ENE,22.2,35.2,0.02,Rain,Light Rain,70,2015-06-01 16:51:00<br />
# 1:51 PM,12.8,11.1,89,1019.9,8.0,ENE,20.4,40.7,0.00,,Overcast,70,2015-06-01 17:51:00<br />
# 2:51 PM,13.3,11.1,87,1019.5,6.4,ENE,25.9,40.7,N/A,,Overcast,70,2015-06-01 18:51:00<br />
# 3:51 PM,13.3,11.1,87,1019.7,8.0,ENE,20.4,35.2,N/A,,Overcast,70,2015-06-01 19:51:00<br />
# 4:51 PM,13.3,11.7,90,1019.6,6.4,ENE,22.2,31.5,N/A,,Overcast,60,2015-06-01 20:51:00<br />
# 5:51 PM,13.3,11.1,87,1019.5,6.4,East,18.5,31.5,N/A,,Overcast,80,2015-06-01 21:51:00<br />
# 6:51 PM,13.3,11.1,87,1019.8,9.7,ENE,18.5,31.5,0.00,,Overcast,70,2015-06-01 22:51:00<br />
# 7:51 PM,12.8,11.1,89,1019.6,9.7,East,13.0,31.5,0.01,Rain,Light Rain,80,2015-06-01 23:51:00<br />
# 8:51 PM,12.2,10.6,90,1020.4,6.4,ENE,27.8,35.2,0.01,,Overcast,70,2015-06-02 00:51:00<br />
# 9:51 PM,12.2,10.6,90,1020.9,6.4,East,14.8,25.9,N/A,,Overcast,80,2015-06-02 01:51:00<br />
# 10:51 PM,11.7,10.0,89,1021.1,8.0,ENE,20.4,31.5,0.03,Rain,Rain,70,2015-06-02 02:51:00<br />
# 11:51 PM,11.1,9.4,89,1021.1,14.5,ENE,22.2,29.6,0.03,Rain,Light Rain,60,2015-06-02 03:51:00<br />

# %% [markdown]
# ### <font color='red'>2.5) Use the regular expression function <i>re.sub()</i> to substitute the <i>br</i> tag with an empty string:</font>

# %%
html_csv_file = re.sub(r'<br />','', html)

# %% [markdown]
# ### <font color='red'>Run the following line to import the new csv-like html as a csv file:</font>

# %%
from StringIO import StringIO
raw_weather_data = pd.read_csv(StringIO(html_csv_file))

# %% [markdown]
# ### <font color='red'>2.6) Print <i>samples</i> of this dataframe</font>

# %%
raw_weather_data.sample()
# Out:
#      TimeEDT  TemperatureC  Dew PointC  Humidity  Sea Level PressurehPa  \
# 19  11:10 AM          12.8        11.7        93                 1020.9
#
#     VisibilityKm Wind Direction  Wind SpeedKm/h Gust SpeedKm/h  \
# 19           3.2           East            16.7           33.3
#
#     Precipitationmm Events Conditions  WindDirDegrees              DateUTC
# 19             0.06   Rain       Rain              80  2015-06-01 15:10:00

# %% [markdown]
# ### <font color='red'>2.7) Keep the following columns in the dataframe : Temperature, Precipitation, Conditions and DateUTC</font>

# %%
col_to_keep = ['TemperatureC','Precipitationmm','Conditions','DateUTC']
raw_weather_data = raw_weather_data[col_to_keep]

# %%
raw_weather_data.head(2)
# Out:
#    TemperatureC  Precipitationmm Conditions              DateUTC
# 0          13.9              0.0   Overcast  2015-06-01 04:51:00
# 1          13.9              NaN   Overcast  2015-06-01 05:51:00

# %% [markdown]
# ### Enrich every day in June

# %% [markdown]
# ### <font color='red'>2.8.1) What is the webpage giving the necessary weather/temperature information in 2015, on June 29th? on July 2nd ?</font>

# %%
url_example = 'https://www.wunderground.com/history/airport/KNYC/2015/6/29/DailyHistory.html?req_city=New+York&req_state=NY&req_statename=New+York&reqdb.zip=10001&reqdb.magic=11&reqdb.wmo=99999'

# %% [markdown]
# ### <font color='red'>2.8.2) Isolate fixed parts of the webpage address (URL)</font>

# %%
def get_url(url_year,url_month,url_day):
    url_prefix = 'https://www.wunderground.com/'
    url_suffix = 'history/airport/KNYC/'
    other ='/DailyHistory.html?req_city=New%20York&req_state=NY&req_statename=New%20York&reqdb.zip=10001&reqdb.magic=5&reqdb.wmo=99999&format=1'
    return url_prefix + url_suffix +str(url_year)+'/'+str(url_month)+'/'+str(url_day)+other

# %%
get_url(2015,6,29)
# Out:
# 'https://www.wunderground.com/history/airport/KNYC/2015/6/29/DailyHistory.html?req_city=New%20York&req_state=NY&req_statename=New%20York&reqdb.zip=10001&reqdb.magic=5&reqdb.wmo=99999&format=1'

# %% [markdown]
# ### <font color='red'>2.9) For every day from May 30th to July 2nd :
# - Scrape weather data from the website using the adequate URL
# - Transform the html file into a csv-like format as we did above
# - Append the result to the existing raw_weather_data dataframe</font>
#
# <b>WARNING</b>: the urls are requested from the Internet, so you might run into connection problems. If this happens, since the data has already been uploaded on the servers, you can request it with the <i>urllib2.urlopen</i> function:
# `urllib2.urlopen('file:///home/data/weather_webpages/weather_{}_{}.html'.format(month, day))`

# %%
raw_weather_data = pd.DataFrame()
count= 0
for month in [5,6,7]:
    if month == 5:
        day_range = [30,31]
    elif month == 6:
        day_range = range(1,31)
    else:
        day_range = [1,2]
        
    for day in day_range:  # make requests for every day of June, and append result to existing Dataframe
        #print 'Collecting weather for Day {} ...'.format(day)
        count +=1
        response = urllib2.urlopen(get_url(2015,month,day))
        html = response.read()
        
        csv_file = re.sub(r'<br />','', html)
        weather_data_day = pd.read_csv(StringIO(csv_file))
        raw_weather_data = raw_weather_data.append(weather_data_day)

# %%
raw_weather_data.to_csv('./appel_API.csv',index=False)

# %% [markdown]
# ### <font color='red'>2.10) Copy the data using <i>.copy()</i> and print samples</font>

# %%
weather_data = raw_weather_data.copy()

# %% [markdown]
# ### <font color='red'>2.11) Transform the DateUTC column to standard datetime format, using <i>pd.to_datetime()</i>. Do not hesitate to add cells to test your code, before assigning the values to the existing dataset.</font>

# %%
weather_data['DateUTC'].head()
# Out:
# 0    2015-05-30 04:51:00
# 1    2015-05-30 05:51:00
# 2    2015-05-30 06:51:00
# 3    2015-05-30 07:51:00
# 4    2015-05-30 08:51:00
# Name: DateUTC, dtype: object

# %%
# Not needed , already in the good format
weather_data.DateUTC = pd.to_datetime(weather_data['DateUTC'], format="%Y-%m-%d %H:%M")

# %% [markdown]
# ### Rounding the timeslots

# %% [markdown]
# ### <font color='red'> Run the following function, which rounds hours </font>

# %%
def round_hour(dt):
    if dt.minute < 30:
        return datetime.datetime(dt.year, dt.month, dt.day, dt.hour)
    else:
        return datetime.datetime(dt.year, dt.month, dt.day, dt.hour) + datetime.timedelta(hours=1)

# %% [markdown]
# ### <font color='red'>2.12) Round the DateUTC hours column with <i>dataframe.column.apply()</i> function</font>

# %%
dt =list(weather_data['DateUTC'])[0]

# %%
datetime.datetime(dt.year, dt.month, dt.day, dt.hour)
# Out:
# datetime.datetime(2015, 5, 30, 4, 0)

# %%
weather_data.DateUTC = weather_data.DateUTC.apply(lambda x: round_hour(x))

# %% [markdown]
# ### <font color='red'>2.13) Show data samples once rounded</font>

# %%
weather_data.sample(3)
# Out:
#     TimeEDT  TemperatureC  Dew PointC  Humidity  Sea Level PressurehPa  \
# 11  9:51 AM          13.3         8.3        72                 1025.6
# 44  6:51 PM          25.6        19.4        68                 1007.2
# 1   1:51 AM          20.0        13.3        65                 1007.7
#
#     VisibilityKm Wind Direction Wind SpeedKm/h Gust SpeedKm/h  \
# 11          16.1           East           11.1              -
# 44          16.1       Variable            7.4              -
# 1           16.1          North        -9999.0              -
#
#     Precipitationmm Events        Conditions  WindDirDegrees  \
# 11              NaN    NaN             Clear              90
# 44             0.01    NaN  Scattered Clouds               0
# 1               NaN    NaN             Clear               0
#
#                DateUTC
# 11 2015-06-04 14:00:00
# 44 2015-06-21 23:00:00
# 1  2015-06-29 06:00:00

# %% [markdown]
# ### <font color='red'>What does the following block do ?</font>

# %%
weather_data = weather_data.groupby('DateUTC', as_index=False).agg({
                                    'Precipitationmm': np.nanmean,
                                    'TemperatureC': np.nanmean,
                                    'Conditions': lambda x: x.value_counts().index[0]
                                    })
# Out:
# /Users/axa/.pyenv/versions/2.7.12/envs/DS/lib/python2.7/site-packages/pandas/core/groupby.py:814: RuntimeWarning: Mean of empty slice
#   f = lambda x: func(x, *args, **kwargs)

# %%
weather_data
# Out:
#                 DateUTC  Precipitationmm        Conditions  TemperatureC
# 0   2015-05-30 05:00:00              NaN             Clear     19.400000
# 1   2015-05-30 06:00:00              NaN             Clear     20.000000
# 2   2015-05-30 07:00:00              NaN             Clear     19.400000
# 3   2015-05-30 08:00:00              NaN             Clear     20.000000
# 4   2015-05-30 09:00:00              NaN             Clear     20.000000
# 5   2015-05-30 10:00:00              NaN             Clear     20.000000
# 6   2015-05-30 11:00:00              NaN             Clear     20.600000
# 7   2015-05-30 12:00:00              NaN             Clear     21.700000
# 8   2015-05-30 13:00:00              NaN             Clear     22.800000
# 9   2015-05-30 14:00:00              NaN     Partly Cloudy     23.900000
# 10  2015-05-30 15:00:00              NaN             Clear     25.000000
# 11  2015-05-30 16:00:00              NaN     Mostly Cloudy     27.033333
# 12  2015-05-30 17:00:00              NaN  Scattered Clouds     27.800000
# 13  2015-05-30 18:00:00              NaN             Clear     28.900000
# 14  2015-05-30 19:00:00              NaN             Clear     28.900000
# 15  2015-05-30 20:00:00              NaN             Clear     27.800000
# 16  2015-05-30 21:00:00              NaN     Partly Cloudy     26.100000
# 17  2015-05-30 22:00:00              NaN             Clear     25.000000
# 18  2015-05-30 23:00:00              NaN             Clear     25.000000
# 19  2015-05-31 00:00:00              NaN             Clear     24.400000
# 20  2015-05-31 01:00:00              NaN             Clear     24.400000
# 21  2015-05-31 02:00:00              NaN             Clear     23.900000
# 22  2015-05-31 03:00:00              NaN             Clear     23.300000
# 23  2015-05-31 04:00:00              NaN             Clear     23.300000
# 24  2015-05-31 05:00:00              NaN             Clear     22.800000
# 25  2015-05-31 06:00:00              NaN             Clear     22.800000
# 26  2015-05-31 07:00:00              NaN             Clear     22.200000
# 27  2015-05-31 08:00:00              NaN             Clear     22.200000
# 28  2015-05-31 09:00:00              NaN             Clear     21.700000
# 29  2015-05-31 10:00:00              NaN  Scattered Clouds     21.700000
# ..                  ...              ...               ...           ...
# 786 2015-07-01 23:00:00              NaN             Clear     27.200000
# 787 2015-07-02 00:00:00              NaN             Clear     27.200000
# 788 2015-07-02 01:00:00              NaN             Clear     26.100000
# 789 2015-07-02 02:00:00              NaN             Clear     25.600000
# 790 2015-07-02 03:00:00              NaN  Scattered Clouds     25.600000
# 791 2015-07-02 04:00:00              NaN             Clear     25.000000
# 792 2015-07-02 05:00:00              NaN             Clear     23.900000
# 793 2015-07-02 06:00:00              NaN             Clear     22.800000
# 794 2015-07-02 07:00:00              NaN             Clear     22.200000
# 795 2015-07-02 08:00:00              NaN             Clear     22.200000
# 796 2015-07-02 09:00:00              NaN             Clear     21.100000
# 797 2015-07-02 10:00:00              NaN             Clear     20.600000
# 798 2015-07-02 11:00:00              NaN             Clear     21.100000
# 799 2015-07-02 12:00:00              NaN  Scattered Clouds     21.700000
# 800 2015-07-02 13:00:00              NaN  Scattered Clouds     22.200000
# 801 2015-07-02 14:00:00              NaN             Clear     23.300000
# 802 2015-07-02 15:00:00              NaN     Mostly Cloudy     24.400000
# 803 2015-07-02 16:00:00              NaN  Scattered Clouds     24.400000
# 804 2015-07-02 17:00:00              NaN     Partly Cloudy     26.100000
# 805 2015-07-02 18:00:00              NaN             Clear     26.100000
# 806 2015-07-02 19:00:00              NaN     Mostly Cloudy     24.400000
# 807 2015-07-02 20:00:00              NaN     Mostly Cloudy     24.400000
# 808 2015-07-02 21:00:00              NaN             Clear     25.000000
# 809 2015-07-02 22:00:00              NaN             Clear     24.400000
# 810 2015-07-02 23:00:00              NaN             Clear     23.300000
# 811 2015-07-03 00:00:00              NaN             Clear     23.300000
# 812 2015-07-03 01:00:00              NaN             Clear     23.300000
# 813 2015-07-03 02:00:00              NaN             Clear     23.300000
# 814 2015-07-03 03:00:00              NaN             Clear     22.800000
# 815 2015-07-03 04:00:00              NaN             Clear     22.200000
#
# [816 rows x 4 columns]

# %% [markdown]
# ### <font color='red'>What do the following blocks do ?</font>

# %%
print 'Missing precipitations values: {:%}'.format(sum(weather_data.Precipitationmm.isnull())/len(weather_data))
# Out:
# Missing precipitations values: 84.926471%

# %%
weather_data.sample(5)
# Out:
#                 DateUTC  Precipitationmm     Conditions  TemperatureC
# 365 2015-06-14 10:00:00              NaN          Clear          22.2
# 291 2015-06-11 08:00:00              NaN  Partly Cloudy          22.8
# 171 2015-06-06 08:00:00              NaN       Overcast          16.1
# 395 2015-06-15 16:00:00              NaN           Haze          26.4
# 218 2015-06-08 07:00:00              NaN       Overcast          17.2

# %% [markdown]
# ### Fill NaN values with forward and backward methods

# %% [markdown]
# ### <font color='red'>Run the following blocks; what do <i>fillna(method='pad')</i> and <i>fillna(method='bfill')</i> do ?</font>

# %%
weather_data[['TemperatureC','Precipitationmm']] = (
    weather_data[['TemperatureC','Precipitationmm']].apply(lambda x: np.round(x,2)))

# %%
weather_data.Precipitationmm.fillna(method="pad", inplace=True)
weather_data.Precipitationmm.fillna(method="bfill", inplace=True)

# %% [markdown]
# ### <font color='red'>2.14) Merge data and weather data</font>

# %%
weather_data.head()
# Out:
#               DateUTC  Precipitationmm Conditions  TemperatureC
# 0 2015-05-30 05:00:00             0.01      Clear          19.4
# 1 2015-05-30 06:00:00             0.01      Clear          20.0
# 2 2015-05-30 07:00:00             0.01      Clear          19.4
# 3 2015-05-30 08:00:00             0.01      Clear          20.0
# 4 2015-05-30 09:00:00             0.01      Clear          20.0

# %%
weather_data.rename(columns = {'DateUTC' : 'join_time'}, inplace=True)  # This renames the weather data Date column
data['join_time'] = data.starttime.apply(round_hour)  # This rounds the time slots for the start time in initial dataset


data = data.merge(weather_data, how='left')


del data['join_time']

# %% [markdown]
# ### <font color='red'>2.15) Show sample observations of <i>data</i></font>

# %%
data.sample()
# Out:
#         tripduration           starttime            stoptime  \
# 162869           248 2015-06-07 13:47:00 2015-06-07 13:51:00
#
#         start station id  start station name  start station latitude  \
# 162869               339  Avenue D & E 12 St               40.725806
#
#         start station longitude  end station id    end station name  \
# 162869               -73.974225             445  E 10 St & Avenue A
#
#         end station latitude  end station longitude  bikeid    usertype  \
# 162869             40.727408              -73.98142   19480  Subscriber
#
#         birth year  gender  Precipitationmm Conditions  TemperatureC
# 162869      1986.0       1              0.0      Clear          18.3

# %% [markdown]
# ## 3) Collect number of available docks <font color='blue'> (20 min) </font>

# %% [markdown]
# ### <font color='red'>3.1) Load stations sizes in response, read the html response and load the json, from the following website:</font>
# - https://www.citibikenyc.com/stations/json

# %%
url ='https://www.citibikenyc.com/stations/json'

# %%
response = urllib2.urlopen(url)
html = response.read()
stations = json.loads(html)

# %% [markdown]
# ### <font color='red'>3.2) Understand the structure of the stations object </font>

# %%
stations
# Out:
# {u'executionTime': u'2017-03-22 10:54:09 AM',
#  u'stationBeanList': [{u'altitude': u'',
#    u'availableBikes': 36,
#    u'availableDocks': 0,
#    u'city': u'',
#    u'id': 72,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:52:55 AM',
#    u'latitude': 40.76727216,
#    u'location': u'',
#    u'longitude': -73.99392888,
#    u'postalCode': u'',
#    u'stAddress1': u'W 52 St & 11 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'W 52 St & 11 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 39},
#   {u'altitude': u'',
#    u'availableBikes': 14,
#    u'availableDocks': 17,
#    u'city': u'',
#    u'id': 79,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:54:04 AM',
#    u'latitude': 40.71911552,
#    u'location': u'',
#    u'longitude': -74.00666661,
#    u'postalCode': u'',
#    u'stAddress1': u'Franklin St & W Broadway',
#    u'stAddress2': u'',
#    u'stationName': u'Franklin St & W Broadway',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 33},
#   {u'altitude': u'',
#    u'availableBikes': 1,
#    u'availableDocks': 26,
#    u'city': u'',
#    u'id': 82,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:51:47 AM',
#    u'latitude': 40.71117416,
#    u'location': u'',
#    u'longitude': -74.00016545,
#    u'postalCode': u'',
#    u'stAddress1': u'St James Pl & Pearl St',
#    u'stAddress2': u'',
#    u'stationName': u'St James Pl & Pearl St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 27},
#   {u'altitude': u'',
#    u'availableBikes': 17,
#    u'availableDocks': 44,
#    u'city': u'',
#    u'id': 83,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:51:51 AM',
#    u'latitude': 40.68382604,
#    u'location': u'',
#    u'longitude': -73.97632328,
#    u'postalCode': u'',
#    u'stAddress1': u'Atlantic Ave & Fort Greene Pl',
#    u'stAddress2': u'',
#    u'stationName': u'Atlantic Ave & Fort Greene Pl',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 62},
#   {u'altitude': u'',
#    u'availableBikes': 20,
#    u'availableDocks': 15,
#    u'city': u'',
#    u'id': 116,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:50:31 AM',
#    u'latitude': 40.74177603,
#    u'location': u'',
#    u'longitude': -74.00149746,
#    u'postalCode': u'',
#    u'stAddress1': u'W 17 St & 8 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'W 17 St & 8 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 39},
#   {u'altitude': u'',
#    u'availableBikes': 9,
#    u'availableDocks': 10,
#    u'city': u'',
#    u'id': 119,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:52:58 AM',
#    u'latitude': 40.69608941,
#    u'location': u'',
#    u'longitude': -73.97803415,
#    u'postalCode': u'',
#    u'stAddress1': u'Park Ave & St Edwards St',
#    u'stAddress2': u'',
#    u'stationName': u'Park Ave & St Edwards St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 19},
#   {u'altitude': u'',
#    u'availableBikes': 4,
#    u'availableDocks': 14,
#    u'city': u'',
#    u'id': 120,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:53:09 AM',
#    u'latitude': 40.68676793,
#    u'location': u'',
#    u'longitude': -73.95928168,
#    u'postalCode': u'',
#    u'stAddress1': u'Lexington Ave & Classon Ave',
#    u'stAddress2': u'',
#    u'stationName': u'Lexington Ave & Classon Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 19},
#   {u'altitude': u'',
#    u'availableBikes': 26,
#    u'availableDocks': 4,
#    u'city': u'',
#    u'id': 127,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:53:10 AM',
#    u'latitude': 40.73172428,
#    u'location': u'',
#    u'longitude': -74.00674436,
#    u'postalCode': u'',
#    u'stAddress1': u'Barrow St & Hudson St',
#    u'stAddress2': u'',
#    u'stationName': u'Barrow St & Hudson St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 31},
#   {u'altitude': u'',
#    u'availableBikes': 28,
#    u'availableDocks': 1,
#    u'city': u'',
#    u'id': 128,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:51:45 AM',
#    u'latitude': 40.72710258,
#    u'location': u'',
#    u'longitude': -74.00297088,
#    u'postalCode': u'',
#    u'stAddress1': u'MacDougal St & Prince St',
#    u'stAddress2': u'',
#    u'stationName': u'MacDougal St & Prince St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 30},
#   {u'altitude': u'',
#    u'availableBikes': 0,
#    u'availableDocks': 0,
#    u'city': u'',
#    u'id': 137,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'1969-12-31 07:00:00 PM',
#    u'latitude': 40.761628,
#    u'location': u'',
#    u'longitude': -73.972924,
#    u'postalCode': u'',
#    u'stAddress1': u'E 56 St & Madison Ave',
#    u'stAddress2': u'',
#    u'stationName': u'E 56 St & Madison Ave',
#    u'statusKey': 3,
#    u'statusValue': u'Not In Service',
#    u'testStation': False,
#    u'totalDocks': 0},
#   {u'altitude': u'',
#    u'availableBikes': 17,
#    u'availableDocks': 1,
#    u'city': u'',
#    u'id': 143,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:50:55 AM',
#    u'latitude': 40.69239502,
#    u'location': u'',
#    u'longitude': -73.99337909,
#    u'postalCode': u'',
#    u'stAddress1': u'Clinton St & Joralemon St',
#    u'stAddress2': u'',
#    u'stationName': u'Clinton St & Joralemon St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 24},
#   {u'altitude': u'',
#    u'availableBikes': 5,
#    u'availableDocks': 14,
#    u'city': u'',
#    u'id': 144,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:50:24 AM',
#    u'latitude': 40.69839895,
#    u'location': u'',
#    u'longitude': -73.98068914,
#    u'postalCode': u'',
#    u'stAddress1': u'Nassau St & Navy St',
#    u'stAddress2': u'',
#    u'stationName': u'Nassau St & Navy St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 19},
#   {u'altitude': u'',
#    u'availableBikes': 5,
#    u'availableDocks': 34,
#    u'city': u'',
#    u'id': 146,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:52:53 AM',
#    u'latitude': 40.71625008,
#    u'location': u'',
#    u'longitude': -74.0091059,
#    u'postalCode': u'',
#    u'stAddress1': u'Hudson St & Reade St',
#    u'stAddress2': u'',
#    u'stationName': u'Hudson St & Reade St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 39},
#   {u'altitude': u'',
#    u'availableBikes': 0,
#    u'availableDocks': 0,
#    u'city': u'',
#    u'id': 147,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-02-23 09:48:26 AM',
#    u'latitude': 40.71542197,
#    u'location': u'',
#    u'longitude': -74.01121978,
#    u'postalCode': u'',
#    u'stAddress1': u'Greenwich St & Warren St',
#    u'stAddress2': u'',
#    u'stationName': u'Greenwich St & Warren St',
#    u'statusKey': 3,
#    u'statusValue': u'Not In Service',
#    u'testStation': False,
#    u'totalDocks': 0},
#   {u'altitude': u'',
#    u'availableBikes': 0,
#    u'availableDocks': 30,
#    u'city': u'',
#    u'id': 150,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:51:05 AM',
#    u'latitude': 40.7208736,
#    u'location': u'',
#    u'longitude': -73.98085795,
#    u'postalCode': u'',
#    u'stAddress1': u'E 2 St & Avenue C',
#    u'stAddress2': u'',
#    u'stationName': u'E 2 St & Avenue C',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 31},
#   {u'altitude': u'',
#    u'availableBikes': 18,
#    u'availableDocks': 11,
#    u'city': u'',
#    u'id': 151,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:51:18 AM',
#    u'latitude': 40.722103786686034,
#    u'location': u'',
#    u'longitude': -73.99724900722504,
#    u'postalCode': u'',
#    u'stAddress1': u'Cleveland Pl & Spring St',
#    u'stAddress2': u'',
#    u'stationName': u'Cleveland Pl & Spring St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 33},
#   {u'altitude': u'',
#    u'availableBikes': 4,
#    u'availableDocks': 24,
#    u'city': u'',
#    u'id': 152,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:52:56 AM',
#    u'latitude': 40.71473993,
#    u'location': u'',
#    u'longitude': -74.00910627,
#    u'postalCode': u'',
#    u'stAddress1': u'Warren St & Church St',
#    u'stAddress2': u'',
#    u'stationName': u'Warren St & Church St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 29},
#   {u'altitude': u'',
#    u'availableBikes': 52,
#    u'availableDocks': 0,
#    u'city': u'',
#    u'id': 153,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:53:19 AM',
#    u'latitude': 40.752062307,
#    u'location': u'',
#    u'longitude': -73.9816324043,
#    u'postalCode': u'',
#    u'stAddress1': u'E 40 St & 5 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'E 40 St & 5 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 55},
#   {u'altitude': u'',
#    u'availableBikes': 17,
#    u'availableDocks': 5,
#    u'city': u'',
#    u'id': 157,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:53:32 AM',
#    u'latitude': 40.69089272,
#    u'location': u'',
#    u'longitude': -73.99612349,
#    u'postalCode': u'',
#    u'stAddress1': u'Henry St & Atlantic Ave',
#    u'stAddress2': u'',
#    u'stationName': u'Henry St & Atlantic Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 23},
#   {u'altitude': u'',
#    u'availableBikes': 15,
#    u'availableDocks': 19,
#    u'city': u'',
#    u'id': 161,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:53:11 AM',
#    u'latitude': 40.72917025,
#    u'location': u'',
#    u'longitude': -73.99810231,
#    u'postalCode': u'',
#    u'stAddress1': u'LaGuardia Pl & W 3 St',
#    u'stAddress2': u'',
#    u'stationName': u'LaGuardia Pl & W 3 St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 35},
#   {u'altitude': u'',
#    u'availableBikes': 41,
#    u'availableDocks': 1,
#    u'city': u'',
#    u'id': 164,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:53:56 AM',
#    u'latitude': 40.75323098,
#    u'location': u'',
#    u'longitude': -73.97032517,
#    u'postalCode': u'',
#    u'stAddress1': u'E 47 St & 2 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'E 47 St & 2 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 47},
#   {u'altitude': u'',
#    u'availableBikes': 18,
#    u'availableDocks': 25,
#    u'city': u'',
#    u'id': 167,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:53:17 AM',
#    u'latitude': 40.7489006,
#    u'location': u'',
#    u'longitude': -73.97604882,
#    u'postalCode': u'',
#    u'stAddress1': u'E 39 St & 3 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'E 39 St & 3 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 45},
#   {u'altitude': u'',
#    u'availableBikes': 34,
#    u'availableDocks': 9,
#    u'city': u'',
#    u'id': 168,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:51:50 AM',
#    u'latitude': 40.73971301,
#    u'location': u'',
#    u'longitude': -73.99456405,
#    u'postalCode': u'',
#    u'stAddress1': u'W 18 St & 6 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'W 18 St & 6 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 47},
#   {u'altitude': u'',
#    u'availableBikes': 36,
#    u'availableDocks': 10,
#    u'city': u'',
#    u'id': 173,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:52:33 AM',
#    u'latitude': 40.76068327096592,
#    u'location': u'',
#    u'longitude': -73.9845272898674,
#    u'postalCode': u'',
#    u'stAddress1': u'Broadway & W 49 St',
#    u'stAddress2': u'',
#    u'stationName': u'Broadway & W 49 St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 51},
#   {u'altitude': u'',
#    u'availableBikes': 9,
#    u'availableDocks': 19,
#    u'city': u'',
#    u'id': 174,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:53:56 AM',
#    u'latitude': 40.7381765,
#    u'location': u'',
#    u'longitude': -73.97738662,
#    u'postalCode': u'',
#    u'stAddress1': u'E 25 St & 1 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'E 25 St & 1 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 30},
#   {u'altitude': u'',
#    u'availableBikes': 14,
#    u'availableDocks': 31,
#    u'city': u'',
#    u'id': 195,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:51:11 AM',
#    u'latitude': 40.70905623,
#    u'location': u'',
#    u'longitude': -74.01043382,
#    u'postalCode': u'',
#    u'stAddress1': u'Liberty St & Broadway',
#    u'stAddress2': u'',
#    u'stationName': u'Liberty St & Broadway',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 45},
#   {u'altitude': u'',
#    u'availableBikes': 23,
#    u'availableDocks': 5,
#    u'city': u'',
#    u'id': 212,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:52:58 AM',
#    u'latitude': 40.74334935,
#    u'location': u'',
#    u'longitude': -74.00681753,
#    u'postalCode': u'',
#    u'stAddress1': u'W 16 St & The High Line',
#    u'stAddress2': u'',
#    u'stationName': u'W 16 St & The High Line',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 28},
#   {u'altitude': u'',
#    u'availableBikes': 7,
#    u'availableDocks': 15,
#    u'city': u'',
#    u'id': 216,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:53:28 AM',
#    u'latitude': 40.70037867,
#    u'location': u'',
#    u'longitude': -73.99548059,
#    u'postalCode': u'',
#    u'stAddress1': u'Columbia Heights & Cranberry St',
#    u'stAddress2': u'',
#    u'stationName': u'Columbia Heights & Cranberry St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 23},
#   {u'altitude': u'',
#    u'availableBikes': 19,
#    u'availableDocks': 20,
#    u'city': u'',
#    u'id': 217,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:52:38 AM',
#    u'latitude': 40.70277159,
#    u'location': u'',
#    u'longitude': -73.99383605,
#    u'postalCode': u'',
#    u'stAddress1': u'Old Fulton St',
#    u'stAddress2': u'',
#    u'stationName': u'Old Fulton St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 39},
#   {u'altitude': u'',
#    u'availableBikes': 0,
#    u'availableDocks': 3,
#    u'city': u'',
#    u'id': 223,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2016-11-22 07:39:47 AM',
#    u'latitude': 40.73781509,
#    u'location': u'',
#    u'longitude': -73.99994661,
#    u'postalCode': u'',
#    u'stAddress1': u'W 13 St & 7 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'W 13 St & 7 Ave',
#    u'statusKey': 3,
#    u'statusValue': u'Not In Service',
#    u'testStation': False,
#    u'totalDocks': 3},
#   {u'altitude': u'',
#    u'availableBikes': 3,
#    u'availableDocks': 28,
#    u'city': u'',
#    u'id': 224,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:51:22 AM',
#    u'latitude': 40.71146364,
#    u'location': u'',
#    u'longitude': -74.00552427,
#    u'postalCode': u'',
#    u'stAddress1': u'Spruce St & Nassau St',
#    u'stAddress2': u'',
#    u'stationName': u'Spruce St & Nassau St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 31},
#   {u'altitude': u'',
#    u'availableBikes': 27,
#    u'availableDocks': 6,
#    u'city': u'',
#    u'id': 225,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:51:07 AM',
#    u'latitude': 40.74195138,
#    u'location': u'',
#    u'longitude': -74.00803013,
#    u'postalCode': u'',
#    u'stAddress1': u'W 14 St & The High Line',
#    u'stAddress2': u'',
#    u'stationName': u'W 14 St & The High Line',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 37},
#   {u'altitude': u'',
#    u'availableBikes': 54,
#    u'availableDocks': 0,
#    u'city': u'',
#    u'id': 228,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:51:42 AM',
#    u'latitude': 40.7546011026,
#    u'location': u'',
#    u'longitude': -73.971878855,
#    u'postalCode': u'',
#    u'stAddress1': u'E 48 St & 3 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'E 48 St & 3 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 55},
#   {u'altitude': u'',
#    u'availableBikes': 21,
#    u'availableDocks': 1,
#    u'city': u'',
#    u'id': 229,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:53:47 AM',
#    u'latitude': 40.72743423,
#    u'location': u'',
#    u'longitude': -73.99379025,
#    u'postalCode': u'',
#    u'stAddress1': u'Great Jones St',
#    u'stAddress2': u'',
#    u'stationName': u'Great Jones St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 23},
#   {u'altitude': u'',
#    u'availableBikes': 6,
#    u'availableDocks': 17,
#    u'city': u'',
#    u'id': 232,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:51:13 AM',
#    u'latitude': 40.69597683,
#    u'location': u'',
#    u'longitude': -73.99014892,
#    u'postalCode': u'',
#    u'stAddress1': u'Cadman Plaza E & Tillary St',
#    u'stAddress2': u'',
#    u'stationName': u'Cadman Plaza E & Tillary St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 23},
#   {u'altitude': u'',
#    u'availableBikes': 10,
#    u'availableDocks': 29,
#    u'city': u'',
#    u'id': 236,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:52:15 AM',
#    u'latitude': 40.7284186,
#    u'location': u'',
#    u'longitude': -73.98713956,
#    u'postalCode': u'',
#    u'stAddress1': u'St Marks Pl & 2 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'St Marks Pl & 2 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 39},
#   {u'altitude': u'',
#    u'availableBikes': 2,
#    u'availableDocks': 36,
#    u'city': u'',
#    u'id': 237,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:52:19 AM',
#    u'latitude': 40.73047309,
#    u'location': u'',
#    u'longitude': -73.98672378,
#    u'postalCode': u'',
#    u'stAddress1': u'E 11 St & 2 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'E 11 St & 2 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 39},
#   {u'altitude': u'',
#    u'availableBikes': 3,
#    u'availableDocks': 27,
#    u'city': u'',
#    u'id': 238,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:52:04 AM',
#    u'latitude': 40.7361967,
#    u'location': u'',
#    u'longitude': -74.00859207,
#    u'postalCode': u'',
#    u'stAddress1': u'Bank St & Washington St',
#    u'stAddress2': u'',
#    u'stationName': u'Bank St & Washington St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 31},
#   {u'altitude': u'',
#    u'availableBikes': 29,
#    u'availableDocks': 2,
#    u'city': u'',
#    u'id': 239,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:53:28 AM',
#    u'latitude': 40.69196566,
#    u'location': u'',
#    u'longitude': -73.9813018,
#    u'postalCode': u'',
#    u'stAddress1': u'Willoughby St & Fleet St',
#    u'stAddress2': u'',
#    u'stationName': u'Willoughby St & Fleet St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 31},
#   {u'altitude': u'',
#    u'availableBikes': 4,
#    u'availableDocks': 19,
#    u'city': u'',
#    u'id': 241,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:51:41 AM',
#    u'latitude': 40.68981035,
#    u'location': u'',
#    u'longitude': -73.97493121,
#    u'postalCode': u'',
#    u'stAddress1': u'DeKalb Ave & S Portland Ave',
#    u'stAddress2': u'',
#    u'stationName': u'DeKalb Ave & S Portland Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 23},
#   {u'altitude': u'',
#    u'availableBikes': 22,
#    u'availableDocks': 0,
#    u'city': u'',
#    u'id': 242,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:54:08 AM',
#    u'latitude': 40.697787,
#    u'location': u'',
#    u'longitude': -73.973736,
#    u'postalCode': u'',
#    u'stAddress1': u'Carlton Ave & Flushing Ave',
#    u'stAddress2': u'',
#    u'stationName': u'Carlton Ave & Flushing Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 23},
#   {u'altitude': u'',
#    u'availableBikes': 29,
#    u'availableDocks': 0,
#    u'city': u'',
#    u'id': 243,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:52:02 AM',
#    u'latitude': 40.688226,
#    u'location': u'',
#    u'longitude': -73.979382,
#    u'postalCode': u'',
#    u'stAddress1': u'Fulton St & Rockwell Pl',
#    u'stAddress2': u'',
#    u'stationName': u'Fulton St & Rockwell Pl',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 31},
#   {u'altitude': u'',
#    u'availableBikes': 2,
#    u'availableDocks': 29,
#    u'city': u'',
#    u'id': 244,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:50:20 AM',
#    u'latitude': 40.69196035,
#    u'location': u'',
#    u'longitude': -73.96536851,
#    u'postalCode': u'',
#    u'stAddress1': u'Willoughby Ave & Hall St',
#    u'stAddress2': u'',
#    u'stationName': u'Willoughby Ave & Hall St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 31},
#   {u'altitude': u'',
#    u'availableBikes': 7,
#    u'availableDocks': 14,
#    u'city': u'',
#    u'id': 245,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:51:51 AM',
#    u'latitude': 40.69327018,
#    u'location': u'',
#    u'longitude': -73.97703874,
#    u'postalCode': u'',
#    u'stAddress1': u'Myrtle Ave & St Edwards St',
#    u'stAddress2': u'',
#    u'stationName': u'Myrtle Ave & St Edwards St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 23},
#   {u'altitude': u'',
#    u'availableBikes': 3,
#    u'availableDocks': 16,
#    u'city': u'',
#    u'id': 247,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:50:11 AM',
#    u'latitude': 40.73535398,
#    u'location': u'',
#    u'longitude': -74.00483091,
#    u'postalCode': u'',
#    u'stAddress1': u'Perry St & Bleecker St',
#    u'stAddress2': u'',
#    u'stationName': u'Perry St & Bleecker St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 20},
#   {u'altitude': u'',
#    u'availableBikes': 22,
#    u'availableDocks': 1,
#    u'city': u'',
#    u'id': 248,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:51:13 AM',
#    u'latitude': 40.72185379,
#    u'location': u'',
#    u'longitude': -74.00771779,
#    u'postalCode': u'',
#    u'stAddress1': u'Laight St & Hudson St',
#    u'stAddress2': u'',
#    u'stationName': u'Laight St & Hudson St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 23},
#   {u'altitude': u'',
#    u'availableBikes': 19,
#    u'availableDocks': 6,
#    u'city': u'',
#    u'id': 249,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:51:53 AM',
#    u'latitude': 40.71870987,
#    u'location': u'',
#    u'longitude': -74.0090009,
#    u'postalCode': u'',
#    u'stAddress1': u'Harrison St & Hudson St',
#    u'stAddress2': u'',
#    u'stationName': u'Harrison St & Hudson St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 27},
#   {u'altitude': u'',
#    u'availableBikes': 22,
#    u'availableDocks': 4,
#    u'city': u'',
#    u'id': 251,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:52:26 AM',
#    u'latitude': 40.72317958,
#    u'location': u'',
#    u'longitude': -73.99480012,
#    u'postalCode': u'',
#    u'stAddress1': u'Mott St & Prince St',
#    u'stAddress2': u'',
#    u'stationName': u'Mott St & Prince St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 27},
#   {u'altitude': u'',
#    u'availableBikes': 24,
#    u'availableDocks': 7,
#    u'city': u'',
#    u'id': 252,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:54:08 AM',
#    u'latitude': 40.73226398,
#    u'location': u'',
#    u'longitude': -73.99852205,
#    u'postalCode': u'',
#    u'stAddress1': u'MacDougal St & Washington Sq',
#    u'stAddress2': u'',
#    u'stationName': u'MacDougal St & Washington Sq',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 33},
#   {u'altitude': u'',
#    u'availableBikes': 23,
#    u'availableDocks': 32,
#    u'city': u'',
#    u'id': 253,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:53:49 AM',
#    u'latitude': 40.73543934,
#    u'location': u'',
#    u'longitude': -73.99453948,
#    u'postalCode': u'',
#    u'stAddress1': u'W 13 St & 5 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'W 13 St & 5 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 55},
#   {u'altitude': u'',
#    u'availableBikes': 13,
#    u'availableDocks': 15,
#    u'city': u'',
#    u'id': 254,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:51:43 AM',
#    u'latitude': 40.73532427,
#    u'location': u'',
#    u'longitude': -73.99800419,
#    u'postalCode': u'',
#    u'stAddress1': u'W 11 St & 6 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'W 11 St & 6 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 31},
#   {u'altitude': u'',
#    u'availableBikes': 29,
#    u'availableDocks': 10,
#    u'city': u'',
#    u'id': 257,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:53:52 AM',
#    u'latitude': 40.71939226,
#    u'location': u'',
#    u'longitude': -74.00247214,
#    u'postalCode': u'',
#    u'stAddress1': u'Lispenard St & Broadway',
#    u'stAddress2': u'',
#    u'stationName': u'Lispenard St & Broadway',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 39},
#   {u'altitude': u'',
#    u'availableBikes': 0,
#    u'availableDocks': 22,
#    u'city': u'',
#    u'id': 258,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:50:21 AM',
#    u'latitude': 40.68940747,
#    u'location': u'',
#    u'longitude': -73.96885458,
#    u'postalCode': u'',
#    u'stAddress1': u'DeKalb Ave & Vanderbilt Ave',
#    u'stAddress2': u'',
#    u'stationName': u'DeKalb Ave & Vanderbilt Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 23},
#   {u'altitude': u'',
#    u'availableBikes': 23,
#    u'availableDocks': 13,
#    u'city': u'',
#    u'id': 259,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:52:14 AM',
#    u'latitude': 40.70122128,
#    u'location': u'',
#    u'longitude': -74.01234218,
#    u'postalCode': u'',
#    u'stAddress1': u'South St & Whitehall St',
#    u'stAddress2': u'',
#    u'stationName': u'South St & Whitehall St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 39},
#   {u'altitude': u'',
#    u'availableBikes': 24,
#    u'availableDocks': 10,
#    u'city': u'',
#    u'id': 260,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:52:54 AM',
#    u'latitude': 40.70365182,
#    u'location': u'',
#    u'longitude': -74.01167797,
#    u'postalCode': u'',
#    u'stAddress1': u'Broad St & Bridge St',
#    u'stAddress2': u'',
#    u'stationName': u'Broad St & Bridge St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 35},
#   {u'altitude': u'',
#    u'availableBikes': 15,
#    u'availableDocks': 11,
#    u'city': u'',
#    u'id': 261,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:53:30 AM',
#    u'latitude': 40.69474881,
#    u'location': u'',
#    u'longitude': -73.98362464,
#    u'postalCode': u'',
#    u'stAddress1': u'Johnson St & Gold St',
#    u'stAddress2': u'',
#    u'stationName': u'Johnson St & Gold St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 27},
#   {u'altitude': u'',
#    u'availableBikes': 1,
#    u'availableDocks': 21,
#    u'city': u'',
#    u'id': 262,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:53:23 AM',
#    u'latitude': 40.6917823,
#    u'location': u'',
#    u'longitude': -73.9737299,
#    u'postalCode': u'',
#    u'stAddress1': u'Washington Park',
#    u'stAddress2': u'',
#    u'stationName': u'Washington Park',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 24},
#   {u'altitude': u'',
#    u'availableBikes': 23,
#    u'availableDocks': 2,
#    u'city': u'',
#    u'id': 264,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:54:00 AM',
#    u'latitude': 40.70706456,
#    u'location': u'',
#    u'longitude': -74.00731853,
#    u'postalCode': u'',
#    u'stAddress1': u'Maiden Ln & Pearl St',
#    u'stAddress2': u'',
#    u'stationName': u'Maiden Ln & Pearl St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 27},
#   {u'altitude': u'',
#    u'availableBikes': 1,
#    u'availableDocks': 34,
#    u'city': u'',
#    u'id': 265,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:52:29 AM',
#    u'latitude': 40.72229346,
#    u'location': u'',
#    u'longitude': -73.99147535,
#    u'postalCode': u'',
#    u'stAddress1': u'Stanton St & Chrystie St',
#    u'stAddress2': u'',
#    u'stationName': u'Stanton St & Chrystie St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 35},
#   {u'altitude': u'',
#    u'availableBikes': 9,
#    u'availableDocks': 15,
#    u'city': u'',
#    u'id': 266,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:51:46 AM',
#    u'latitude': 40.72368361,
#    u'location': u'',
#    u'longitude': -73.97574813,
#    u'postalCode': u'',
#    u'stAddress1': u'Avenue D & E 8 St',
#    u'stAddress2': u'',
#    u'stationName': u'Avenue D & E 8 St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 24},
#   {u'altitude': u'',
#    u'availableBikes': 1,
#    u'availableDocks': 35,
#    u'city': u'',
#    u'id': 267,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:52:29 AM',
#    u'latitude': 40.75097711,
#    u'location': u'',
#    u'longitude': -73.98765428,
#    u'postalCode': u'',
#    u'stAddress1': u'Broadway & W 36 St',
#    u'stAddress2': u'',
#    u'stationName': u'Broadway & W 36 St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 57},
#   {u'altitude': u'',
#    u'availableBikes': 16,
#    u'availableDocks': 10,
#    u'city': u'',
#    u'id': 268,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:53:32 AM',
#    u'latitude': 40.71910537,
#    u'location': u'',
#    u'longitude': -73.99973337,
#    u'postalCode': u'',
#    u'stAddress1': u'Howard St & Centre St',
#    u'stAddress2': u'',
#    u'stationName': u'Howard St & Centre St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 27},
#   {u'altitude': u'',
#    u'availableBikes': 1,
#    u'availableDocks': 18,
#    u'city': u'',
#    u'id': 270,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:53:15 AM',
#    u'latitude': 40.69308257,
#    u'location': u'',
#    u'longitude': -73.97178913,
#    u'postalCode': u'',
#    u'stAddress1': u'Adelphi St & Myrtle Ave',
#    u'stAddress2': u'',
#    u'stationName': u'Adelphi St & Myrtle Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 23},
#   {u'altitude': u'',
#    u'availableBikes': 16,
#    u'availableDocks': 13,
#    u'city': u'',
#    u'id': 274,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:52:16 AM',
#    u'latitude': 40.68691865,
#    u'location': u'',
#    u'longitude': -73.976682,
#    u'postalCode': u'',
#    u'stAddress1': u'Lafayette Ave & Fort Greene Pl',
#    u'stAddress2': u'',
#    u'stationName': u'Lafayette Ave & Fort Greene Pl',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 31},
#   {u'altitude': u'',
#    u'availableBikes': 0,
#    u'availableDocks': 19,
#    u'city': u'',
#    u'id': 275,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:51:30 AM',
#    u'latitude': 40.68650065,
#    u'location': u'',
#    u'longitude': -73.96563307,
#    u'postalCode': u'',
#    u'stAddress1': u'Washington Ave & Greene Ave',
#    u'stAddress2': u'',
#    u'stationName': u'Washington Ave & Greene Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 19},
#   {u'altitude': u'',
#    u'availableBikes': 13,
#    u'availableDocks': 12,
#    u'city': u'',
#    u'id': 276,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:52:03 AM',
#    u'latitude': 40.71748752,
#    u'location': u'',
#    u'longitude': -74.0104554,
#    u'postalCode': u'',
#    u'stAddress1': u'Duane St & Greenwich St',
#    u'stAddress2': u'',
#    u'stationName': u'Duane St & Greenwich St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 25},
#   {u'altitude': u'',
#    u'availableBikes': 7,
#    u'availableDocks': 12,
#    u'city': u'',
#    u'id': 278,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:53:29 AM',
#    u'latitude': 40.69766564,
#    u'location': u'',
#    u'longitude': -73.98476437,
#    u'postalCode': u'',
#    u'stAddress1': u'Concord St & Bridge St',
#    u'stAddress2': u'',
#    u'stationName': u'Concord St & Bridge St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 19},
#   {u'altitude': u'',
#    u'availableBikes': 35,
#    u'availableDocks': 0,
#    u'city': u'',
#    u'id': 279,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:50:15 AM',
#    u'latitude': 40.707873,
#    u'location': u'',
#    u'longitude': -74.00167,
#    u'postalCode': u'',
#    u'stAddress1': u'Peck Slip & Front St',
#    u'stAddress2': u'',
#    u'stationName': u'Peck Slip & Front St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 36},
#   {u'altitude': u'',
#    u'availableBikes': 22,
#    u'availableDocks': 7,
#    u'city': u'',
#    u'id': 280,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:53:34 AM',
#    u'latitude': 40.73331967,
#    u'location': u'',
#    u'longitude': -73.99510132,
#    u'postalCode': u'',
#    u'stAddress1': u'E 10 St & 5 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'E 10 St & 5 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 31},
#   {u'altitude': u'',
#    u'availableBikes': 51,
#    u'availableDocks': 4,
#    u'city': u'',
#    u'id': 281,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:53:46 AM',
#    u'latitude': 40.7643971,
#    u'location': u'',
#    u'longitude': -73.97371465,
#    u'postalCode': u'',
#    u'stAddress1': u'Grand Army Plaza & Central Park S',
#    u'stAddress2': u'',
#    u'stationName': u'Grand Army Plaza & Central Park S',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 59},
#   {u'altitude': u'',
#    u'availableBikes': 12,
#    u'availableDocks': 15,
#    u'city': u'',
#    u'id': 282,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:53:35 AM',
#    u'latitude': 40.707644944175705,
#    u'location': u'',
#    u'longitude': -73.96841526031494,
#    u'postalCode': u'',
#    u'stAddress1': u'Kent Ave & S 11 St',
#    u'stAddress2': u'',
#    u'stationName': u'Kent Ave & S 11 St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 27},
#   {u'altitude': u'',
#    u'availableBikes': 37,
#    u'availableDocks': 2,
#    u'city': u'',
#    u'id': 284,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:50:53 AM',
#    u'latitude': 40.7390169121,
#    u'location': u'',
#    u'longitude': -74.0026376103,
#    u'postalCode': u'',
#    u'stAddress1': u'Greenwich Ave & 8 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'Greenwich Ave & 8 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 43},
#   {u'altitude': u'',
#    u'availableBikes': 21,
#    u'availableDocks': 25,
#    u'city': u'',
#    u'id': 285,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:51:21 AM',
#    u'latitude': 40.73454567,
#    u'location': u'',
#    u'longitude': -73.99074142,
#    u'postalCode': u'',
#    u'stAddress1': u'Broadway & E 14 St',
#    u'stAddress2': u'',
#    u'stationName': u'Broadway & E 14 St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 47},
#   {u'altitude': u'',
#    u'availableBikes': 1,
#    u'availableDocks': 17,
#    u'city': u'',
#    u'id': 289,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:53:44 AM',
#    u'latitude': 40.6845683,
#    u'location': u'',
#    u'longitude': -73.95881081,
#    u'postalCode': u'',
#    u'stAddress1': u'Monroe St & Classon Ave',
#    u'stAddress2': u'',
#    u'stationName': u'Monroe St & Classon Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 19},
#   {u'altitude': u'',
#    u'availableBikes': 5,
#    u'availableDocks': 13,
#    u'city': u'',
#    u'id': 291,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:52:13 AM',
#    u'latitude': 40.713126,
#    u'location': u'',
#    u'longitude': -73.984844,
#    u'postalCode': u'',
#    u'stAddress1': u'Madison St & Montgomery St',
#    u'stAddress2': u'',
#    u'stationName': u'Madison St & Montgomery St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 20},
#   {u'altitude': u'',
#    u'availableBikes': 28,
#    u'availableDocks': 26,
#    u'city': u'',
#    u'id': 293,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:53:50 AM',
#    u'latitude': 40.73028666,
#    u'location': u'',
#    u'longitude': -73.9907647,
#    u'postalCode': u'',
#    u'stAddress1': u'Lafayette St & E 8 St',
#    u'stAddress2': u'',
#    u'stationName': u'Lafayette St & E 8 St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 55},
#   {u'altitude': u'',
#    u'availableBikes': 11,
#    u'availableDocks': 11,
#    u'city': u'',
#    u'id': 295,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:50:29 AM',
#    u'latitude': 40.71406667,
#    u'location': u'',
#    u'longitude': -73.99293911,
#    u'postalCode': u'',
#    u'stAddress1': u'Pike St & E Broadway',
#    u'stAddress2': u'',
#    u'stationName': u'Pike St & E Broadway',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 24},
#   {u'altitude': u'',
#    u'availableBikes': 12,
#    u'availableDocks': 23,
#    u'city': u'',
#    u'id': 296,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:54:02 AM',
#    u'latitude': 40.71413089,
#    u'location': u'',
#    u'longitude': -73.9970468,
#    u'postalCode': u'',
#    u'stAddress1': u'Division St & Bowery',
#    u'stAddress2': u'',
#    u'stationName': u'Division St & Bowery',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 35},
#   {u'altitude': u'',
#    u'availableBikes': 18,
#    u'availableDocks': 9,
#    u'city': u'',
#    u'id': 297,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:53:53 AM',
#    u'latitude': 40.734232,
#    u'location': u'',
#    u'longitude': -73.986923,
#    u'postalCode': u'',
#    u'stAddress1': u'E 15 St & 3 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'E 15 St & 3 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 27},
#   {u'altitude': u'',
#    u'availableBikes': 0,
#    u'availableDocks': 36,
#    u'city': u'',
#    u'id': 301,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:51:51 AM',
#    u'latitude': 40.72217444,
#    u'location': u'',
#    u'longitude': -73.98368779,
#    u'postalCode': u'',
#    u'stAddress1': u'E 2 St & Avenue B',
#    u'stAddress2': u'',
#    u'stationName': u'E 2 St & Avenue B',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 37},
#   {u'altitude': u'',
#    u'availableBikes': 3,
#    u'availableDocks': 20,
#    u'city': u'',
#    u'id': 302,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:53:08 AM',
#    u'latitude': 40.72082834,
#    u'location': u'',
#    u'longitude': -73.97793172,
#    u'postalCode': u'',
#    u'stAddress1': u'Avenue D & E 3 St',
#    u'stAddress2': u'',
#    u'stationName': u'Avenue D & E 3 St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 23},
#   {u'altitude': u'',
#    u'availableBikes': 23,
#    u'availableDocks': 7,
#    u'city': u'',
#    u'id': 303,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:52:51 AM',
#    u'latitude': 40.72362738,
#    u'location': u'',
#    u'longitude': -73.99949601,
#    u'postalCode': u'',
#    u'stAddress1': u'Mercer St & Spring St',
#    u'stAddress2': u'',
#    u'stationName': u'Mercer St & Spring St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 31},
#   {u'altitude': u'',
#    u'availableBikes': 21,
#    u'availableDocks': 13,
#    u'city': u'',
#    u'id': 304,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:50:48 AM',
#    u'latitude': 40.70463334,
#    u'location': u'',
#    u'longitude': -74.01361706,
#    u'postalCode': u'',
#    u'stAddress1': u'Broadway & Battery Pl',
#    u'stAddress2': u'',
#    u'stationName': u'Broadway & Battery Pl',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 34},
#   {u'altitude': u'',
#    u'availableBikes': 32,
#    u'availableDocks': 0,
#    u'city': u'',
#    u'id': 305,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:52:05 AM',
#    u'latitude': 40.76095756,
#    u'location': u'',
#    u'longitude': -73.96724467,
#    u'postalCode': u'',
#    u'stAddress1': u'E 58 St & 3 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'E 58 St & 3 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 33},
#   {u'altitude': u'',
#    u'availableBikes': 32,
#    u'availableDocks': 5,
#    u'city': u'',
#    u'id': 306,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:50:34 AM',
#    u'latitude': 40.70823502,
#    u'location': u'',
#    u'longitude': -74.00530063,
#    u'postalCode': u'',
#    u'stAddress1': u'Cliff St & Fulton St',
#    u'stAddress2': u'',
#    u'stationName': u'Cliff St & Fulton St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 37},
#   {u'altitude': u'',
#    u'availableBikes': 21,
#    u'availableDocks': 7,
#    u'city': u'',
#    u'id': 307,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:52:50 AM',
#    u'latitude': 40.71427487,
#    u'location': u'',
#    u'longitude': -73.98990025,
#    u'postalCode': u'',
#    u'stAddress1': u'Canal St & Rutgers St',
#    u'stAddress2': u'',
#    u'stationName': u'Canal St & Rutgers St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 29},
#   {u'altitude': u'',
#    u'availableBikes': 1,
#    u'availableDocks': 26,
#    u'city': u'',
#    u'id': 308,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:50:45 AM',
#    u'latitude': 40.71307916,
#    u'location': u'',
#    u'longitude': -73.99851193,
#    u'postalCode': u'',
#    u'stAddress1': u'St James Pl & Oliver St',
#    u'stAddress2': u'',
#    u'stationName': u'St James Pl & Oliver St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 27},
#   {u'altitude': u'',
#    u'availableBikes': 35,
#    u'availableDocks': 1,
#    u'city': u'',
#    u'id': 309,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:50:51 AM',
#    u'latitude': 40.7149787,
#    u'location': u'',
#    u'longitude': -74.013012,
#    u'postalCode': u'',
#    u'stAddress1': u'Murray St & West St',
#    u'stAddress2': u'',
#    u'stationName': u'Murray St & West St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 41},
#   {u'altitude': u'',
#    u'availableBikes': 15,
#    u'availableDocks': 21,
#    u'city': u'',
#    u'id': 310,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:53:27 AM',
#    u'latitude': 40.68926942,
#    u'location': u'',
#    u'longitude': -73.98912867,
#    u'postalCode': u'',
#    u'stAddress1': u'State St & Smith St',
#    u'stAddress2': u'',
#    u'stationName': u'State St & Smith St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 36},
#   {u'altitude': u'',
#    u'availableBikes': 10,
#    u'availableDocks': 20,
#    u'city': u'',
#    u'id': 311,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:51:43 AM',
#    u'latitude': 40.7172274,
#    u'location': u'',
#    u'longitude': -73.98802084,
#    u'postalCode': u'',
#    u'stAddress1': u'Norfolk St & Broome St',
#    u'stAddress2': u'',
#    u'stationName': u'Norfolk St & Broome St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 31},
#   {u'altitude': u'',
#    u'availableBikes': 0,
#    u'availableDocks': 31,
#    u'city': u'',
#    u'id': 312,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:51:22 AM',
#    u'latitude': 40.722055,
#    u'location': u'',
#    u'longitude': -73.989111,
#    u'postalCode': u'',
#    u'stAddress1': u'Allen St & Stanton St',
#    u'stAddress2': u'',
#    u'stationName': u'Allen St & Stanton St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 31},
#   {u'altitude': u'',
#    u'availableBikes': 23,
#    u'availableDocks': 0,
#    u'city': u'',
#    u'id': 313,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:52:14 AM',
#    u'latitude': 40.69610226,
#    u'location': u'',
#    u'longitude': -73.96751037,
#    u'postalCode': u'',
#    u'stAddress1': u'Washington Ave & Park Ave',
#    u'stAddress2': u'',
#    u'stationName': u'Washington Ave & Park Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 23},
#   {u'altitude': u'',
#    u'availableBikes': 24,
#    u'availableDocks': 2,
#    u'city': u'',
#    u'id': 315,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:54:00 AM',
#    u'latitude': 40.70355377,
#    u'location': u'',
#    u'longitude': -74.00670227,
#    u'postalCode': u'',
#    u'stAddress1': u'South St & Gouverneur Ln',
#    u'stAddress2': u'',
#    u'stationName': u'South St & Gouverneur Ln',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 29},
#   {u'altitude': u'',
#    u'availableBikes': 3,
#    u'availableDocks': 40,
#    u'city': u'',
#    u'id': 316,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:50:51 AM',
#    u'latitude': 40.70955958,
#    u'location': u'',
#    u'longitude': -74.00653609,
#    u'postalCode': u'',
#    u'stAddress1': u'Fulton St & William St',
#    u'stAddress2': u'',
#    u'stationName': u'Fulton St & William St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 43},
#   {u'altitude': u'',
#    u'availableBikes': 0,
#    u'availableDocks': 26,
#    u'city': u'',
#    u'id': 317,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:53:33 AM',
#    u'latitude': 40.72453734,
#    u'location': u'',
#    u'longitude': -73.98185424,
#    u'postalCode': u'',
#    u'stAddress1': u'E 6 St & Avenue B',
#    u'stAddress2': u'',
#    u'stationName': u'E 6 St & Avenue B',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 27},
#   {u'altitude': u'',
#    u'availableBikes': 11,
#    u'availableDocks': 22,
#    u'city': u'',
#    u'id': 319,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:53:41 AM',
#    u'latitude': 40.711066,
#    u'location': u'',
#    u'longitude': -74.009447,
#    u'postalCode': u'',
#    u'stAddress1': u'Fulton St & Broadway',
#    u'stAddress2': u'',
#    u'stationName': u'Fulton St & Broadway',
#    u'statusKey': 1,
# ...
#    u'location': u'',
#    u'longitude': -73.98302136,
#    u'postalCode': u'',
#    u'stAddress1': u'Pacific St & Nevins St',
#    u'stAddress2': u'',
#    u'stationName': u'Pacific St & Nevins St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 18},
#   {u'altitude': u'',
#    u'availableBikes': 18,
#    u'availableDocks': 3,
#    u'city': u'',
#    u'id': 3413,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:53:03 AM',
#    u'latitude': 40.6827549,
#    u'location': u'',
#    u'longitude': -73.98258555,
#    u'postalCode': u'',
#    u'stAddress1': u'Wyckoff St & 3 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'Wyckoff St & 3 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 22},
#   {u'altitude': u'',
#    u'availableBikes': 20,
#    u'availableDocks': 13,
#    u'city': u'',
#    u'id': 3414,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:53:57 AM',
#    u'latitude': 40.680944723477296,
#    u'location': u'',
#    u'longitude': -73.97567331790923,
#    u'postalCode': u'',
#    u'stAddress1': u'Bergen St & Flatbush Ave',
#    u'stAddress2': u'',
#    u'stationName': u'Bergen St & Flatbush Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 33},
#   {u'altitude': u'',
#    u'availableBikes': 24,
#    u'availableDocks': 0,
#    u'city': u'',
#    u'id': 3415,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:51:45 AM',
#    u'latitude': 40.6793307,
#    u'location': u'',
#    u'longitude': -73.97519523,
#    u'postalCode': u'',
#    u'stAddress1': u'Prospect Pl & 6 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'Prospect Pl & 6 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 25},
#   {u'altitude': u'',
#    u'availableBikes': 12,
#    u'availableDocks': 3,
#    u'city': u'',
#    u'id': 3416,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:52:31 AM',
#    u'latitude': 40.6776147,
#    u'location': u'',
#    u'longitude': -73.97324283,
#    u'postalCode': u'',
#    u'stAddress1': u'7 Ave & Park Pl',
#    u'stAddress2': u'',
#    u'stationName': u'7 Ave & Park Pl',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 17},
#   {u'altitude': u'',
#    u'availableBikes': 23,
#    u'availableDocks': 4,
#    u'city': u'',
#    u'id': 3417,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:52:24 AM',
#    u'latitude': 40.6795766,
#    u'location': u'',
#    u'longitude': -73.97854971,
#    u'postalCode': u'',
#    u'stAddress1': u'Baltic St & 5 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'Baltic St & 5 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 27},
#   {u'altitude': u'',
#    u'availableBikes': 5,
#    u'availableDocks': 27,
#    u'city': u'',
#    u'id': 3418,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:51:04 AM',
#    u'latitude': 40.6750207,
#    u'location': u'',
#    u'longitude': -73.97111473,
#    u'postalCode': u'',
#    u'stAddress1': u'Plaza St West & Flatbush Ave',
#    u'stAddress2': u'',
#    u'stationName': u'Plaza St West & Flatbush Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 33},
#   {u'altitude': u'',
#    u'availableBikes': 22,
#    u'availableDocks': 5,
#    u'city': u'',
#    u'id': 3419,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:53:54 AM',
#    u'latitude': 40.6792788,
#    u'location': u'',
#    u'longitude': -73.98154004,
#    u'postalCode': u'',
#    u'stAddress1': u'Douglass St & 4 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'Douglass St & 4 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 27},
#   {u'altitude': u'',
#    u'availableBikes': 17,
#    u'availableDocks': 4,
#    u'city': u'',
#    u'id': 3420,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:50:55 AM',
#    u'latitude': 40.6802133,
#    u'location': u'',
#    u'longitude': -73.98432695,
#    u'postalCode': u'',
#    u'stAddress1': u'Douglass St & 3 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'Douglass St & 3 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 21},
#   {u'altitude': u'',
#    u'availableBikes': 22,
#    u'availableDocks': 1,
#    u'city': u'',
#    u'id': 3421,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:52:21 AM',
#    u'latitude': 40.6843549,
#    u'location': u'',
#    u'longitude': -73.98901629,
#    u'postalCode': u'',
#    u'stAddress1': u'Hoyt St & Warren St',
#    u'stAddress2': u'',
#    u'stationName': u'Hoyt St & Warren St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 23},
#   {u'altitude': u'',
#    u'availableBikes': 14,
#    u'availableDocks': 6,
#    u'city': u'',
#    u'id': 3422,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:52:04 AM',
#    u'latitude': 40.6859296,
#    u'location': u'',
#    u'longitude': -74.00242364,
#    u'postalCode': u'',
#    u'stAddress1': u'Columbia St & Degraw St',
#    u'stAddress2': u'',
#    u'stationName': u'Columbia St & Degraw St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 21},
#   {u'altitude': u'',
#    u'availableBikes': 8,
#    u'availableDocks': 21,
#    u'city': u'',
#    u'id': 3423,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:53:41 AM',
#    u'latitude': 40.6610633719006,
#    u'location': u'',
#    u'longitude': -73.97945255041122,
#    u'postalCode': u'',
#    u'stAddress1': u'West Drive & Prospect Park West',
#    u'stAddress2': u'',
#    u'stationName': u'West Drive & Prospect Park West',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 29},
#   {u'altitude': u'',
#    u'availableBikes': 9,
#    u'availableDocks': 18,
#    u'city': u'',
#    u'id': 3424,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:51:08 AM',
#    u'latitude': 40.791976,
#    u'location': u'',
#    u'longitude': -73.945993,
#    u'postalCode': u'',
#    u'stAddress1': u'E 106 St & Lexington Ave',
#    u'stAddress2': u'',
#    u'stationName': u'E 106 St & Lexington Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 27},
#   {u'altitude': u'',
#    u'availableBikes': 4,
#    u'availableDocks': 28,
#    u'city': u'',
#    u'id': 3425,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:50:32 AM',
#    u'latitude': 40.7892105,
#    u'location': u'',
#    u'longitude': -73.94370784,
#    u'postalCode': u'',
#    u'stAddress1': u'2 Ave  & E 104 St',
#    u'stAddress2': u'',
#    u'stationName': u'2 Ave  & E 104 St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 33},
#   {u'altitude': u'',
#    u'availableBikes': 28,
#    u'availableDocks': 8,
#    u'city': u'',
#    u'id': 3427,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:53:24 AM',
#    u'latitude': 40.72430527250332,
#    u'location': u'',
#    u'longitude': -73.99600982666016,
#    u'postalCode': u'',
#    u'stAddress1': u'Lafayette St & Jersey St',
#    u'stAddress2': u'',
#    u'stationName': u'Lafayette St & Jersey St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 40},
#   {u'altitude': u'',
#    u'availableBikes': 21,
#    u'availableDocks': 4,
#    u'city': u'',
#    u'id': 3428,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:53:02 AM',
#    u'latitude': 40.740983,
#    u'location': u'',
#    u'longitude': -74.001702,
#    u'postalCode': u'',
#    u'stAddress1': u'8 Ave & W 16 St',
#    u'stAddress2': u'',
#    u'stationName': u'8 Ave & W 16 St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 25},
#   {u'altitude': u'',
#    u'availableBikes': 14,
#    u'availableDocks': 25,
#    u'city': u'',
#    u'id': 3429,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:52:32 AM',
#    u'latitude': 40.68506807308177,
#    u'location': u'',
#    u'longitude': -73.97790759801863,
#    u'postalCode': u'',
#    u'stAddress1': u'Hanson Pl & Ashland Pl',
#    u'stAddress2': u'',
#    u'stationName': u'Hanson Pl & Ashland Pl',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 39},
#   {u'altitude': u'',
#    u'availableBikes': 0,
#    u'availableDocks': 19,
#    u'city': u'',
#    u'id': 3430,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:53:50 AM',
#    u'latitude': 40.71907891179564,
#    u'location': u'',
#    u'longitude': -73.94223690032959,
#    u'postalCode': u'',
#    u'stAddress1': u'Richardson St & N Henry St',
#    u'stAddress2': u'',
#    u'stationName': u'Richardson St & N Henry St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 19},
#   {u'altitude': u'',
#    u'availableBikes': 0,
#    u'availableDocks': 26,
#    u'city': u'',
#    u'id': 3431,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:51:49 AM',
#    u'latitude': 40.746524,
#    u'location': u'',
#    u'longitude': -73.977885,
#    u'postalCode': u'',
#    u'stAddress1': u'E 35 St & 3 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'E 35 St & 3 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 26},
#   {u'altitude': u'',
#    u'availableBikes': 0,
#    u'availableDocks': 35,
#    u'city': u'',
#    u'id': 3434,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:53:35 AM',
#    u'latitude': 40.79025417330419,
#    u'location': u'',
#    u'longitude': -73.97718340158461,
#    u'postalCode': u'',
#    u'stAddress1': u'W 88 St & West End Ave',
#    u'stAddress2': u'',
#    u'stationName': u'W 88 St & West End Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 35},
#   {u'altitude': u'',
#    u'availableBikes': 11,
#    u'availableDocks': 32,
#    u'city': u'',
#    u'id': 3435,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:50:21 AM',
#    u'latitude': 40.718822,
#    u'location': u'',
#    u'longitude': -73.99596,
#    u'postalCode': u'',
#    u'stAddress1': u'Grand St & Elizabeth St',
#    u'stAddress2': u'',
#    u'stationName': u'Grand St & Elizabeth St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 45},
#   {u'altitude': u'',
#    u'availableBikes': 31,
#    u'availableDocks': 0,
#    u'city': u'',
#    u'id': 3436,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:53:00 AM',
#    u'latitude': 40.721319,
#    u'location': u'',
#    u'longitude': -74.010065,
#    u'postalCode': u'',
#    u'stAddress1': u'Greenwich St & Hubert St',
#    u'stAddress2': u'',
#    u'stationName': u'Greenwich St & Hubert St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 31},
#   {u'altitude': u'',
#    u'availableBikes': 11,
#    u'availableDocks': 19,
#    u'city': u'',
#    u'id': 3438,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:52:17 AM',
#    u'latitude': 40.772248537721744,
#    u'location': u'',
#    u'longitude': -73.95842134952545,
#    u'postalCode': u'',
#    u'stAddress1': u'E 76 St & 3 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'E 76 St & 3 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 31},
#   {u'altitude': u'',
#    u'availableBikes': 35,
#    u'availableDocks': 7,
#    u'city': u'',
#    u'id': 3440,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:52:48 AM',
#    u'latitude': 40.692418292578466,
#    u'location': u'',
#    u'longitude': -73.98949474096298,
#    u'postalCode': u'',
#    u'stAddress1': u'Fulton St & Adams St',
#    u'stAddress2': u'',
#    u'stationName': u'Fulton St & Adams St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 43},
#   {u'altitude': u'',
#    u'availableBikes': 5,
#    u'availableDocks': 36,
#    u'city': u'',
#    u'id': 3443,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:51:08 AM',
#    u'latitude': 40.76132983124814,
#    u'location': u'',
#    u'longitude': -73.97982001304626,
#    u'postalCode': u'',
#    u'stAddress1': u'W 52 St & 6 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'W 52 St & 6 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 41},
#   {u'altitude': u'',
#    u'availableBikes': 6,
#    u'availableDocks': 33,
#    u'city': u'',
#    u'id': 3445,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:52:45 AM',
#    u'latitude': 40.79181171501097,
#    u'location': u'',
#    u'longitude': -73.9786022901535,
#    u'postalCode': u'',
#    u'stAddress1': u'Riverside Dr & W 89 St',
#    u'stAddress2': u'',
#    u'stationName': u'Riverside Dr & W 89 St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 39},
#   {u'altitude': u'',
#    u'availableBikes': 31,
#    u'availableDocks': 10,
#    u'city': u'',
#    u'id': 3447,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:53:04 AM',
#    u'latitude': 40.76703432309872,
#    u'location': u'',
#    u'longitude': -73.95622730255127,
#    u'postalCode': u'',
#    u'stAddress1': u'E 71 St & 1 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'E 71 St & 1 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 41},
#   {u'altitude': u'',
#    u'availableBikes': 0,
#    u'availableDocks': 18,
#    u'city': u'',
#    u'id': 3449,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:52:59 AM',
#    u'latitude': 40.721462562298164,
#    u'location': u'',
#    u'longitude': -73.94800901412964,
#    u'postalCode': u'',
#    u'stAddress1': u'Eckford St & Engert Ave',
#    u'stAddress2': u'',
#    u'stationName': u'Eckford St & Engert Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 18},
#   {u'altitude': u'',
#    u'availableBikes': 11,
#    u'availableDocks': 32,
#    u'city': u'',
#    u'id': 3452,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:51:43 AM',
#    u'latitude': 40.71915571696044,
#    u'location': u'',
#    u'longitude': -73.94885390996933,
#    u'postalCode': u'',
#    u'stAddress1': u'Bayard St & Leonard St',
#    u'stAddress2': u'',
#    u'stationName': u'Bayard St & Leonard St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 43},
#   {u'altitude': u'',
#    u'availableBikes': 4,
#    u'availableDocks': 15,
#    u'city': u'',
#    u'id': 3453,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:53:22 AM',
#    u'latitude': 40.71335226222875,
#    u'location': u'',
#    u'longitude': -73.9491033554077,
#    u'postalCode': u'',
#    u'stAddress1': u'Devoe St & Lorimer St',
#    u'stAddress2': u'',
#    u'stationName': u'Devoe St & Lorimer St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 19},
#   {u'altitude': u'',
#    u'availableBikes': 8,
#    u'availableDocks': 15,
#    u'city': u'',
#    u'id': 3454,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:53:24 AM',
#    u'latitude': 40.7103685423523,
#    u'location': u'',
#    u'longitude': -73.94705951213837,
#    u'postalCode': u'',
#    u'stAddress1': u'Leonard St & Maujer St',
#    u'stAddress2': u'',
#    u'stationName': u'Leonard St & Maujer St',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 24},
#   {u'altitude': u'',
#    u'availableBikes': 25,
#    u'availableDocks': 8,
#    u'city': u'',
#    u'id': 3455,
#    u'landMark': u'',
#    u'lastCommunicationTime': u'2017-03-22 10:51:06 AM',
#    u'latitude': 40.68680820503432,
#    u'location': u'',
#    u'longitude': -73.98036181926727,
#    u'postalCode': u'',
#    u'stAddress1': u'Schermerhorn St & 3 Ave',
#    u'stAddress2': u'',
#    u'stationName': u'Schermerhorn St & 3 Ave',
#    u'statusKey': 1,
#    u'statusValue': u'In Service',
#    u'testStation': False,
#    u'totalDocks': 35}]}

# %%
stations.keys()
# Out:
# [u'executionTime', u'stationBeanList']

# %% [markdown]
# ### <font color='red'>Run the following block that groups the stations ids and capacities in a dictionary </font>

# %%
total_docks = dict()

for x in stations['stationBeanList']:
    total_docks.update({x['id']:x['totalDocks']})

# %% [markdown]
# ### <font color='red'>3.3) Create a pandas Dataframe from <i>total_docks</i> using pd.DataFrame.from_dict()</font>

# %%
stations_df =pd.DataFrame(total_docks.items())
stations_df.columns = ['start station id','total_docks_start']  # This renames the columns of the created DataFrame

# %% [markdown]
# ### <font color='red'>3.4) Show a sample of the created DataFrame</font>

# %%
stations_df.sample()
# Out:
#      start station id  total_docks_start
# 162              3258                 37

# %% [markdown]
# ### <font color='red'>3.5) Left merge data and start stations capacities using <i>data.merge()</i></font>

# %%
data =data.merge(stations_df)

# %% [markdown]
# ### <font color='red'>3.6) Left merge data and end stations capacities using <i>data.merge()</i></font>

# %%
stations_df.rename(columns = {'start station id': 'end station id',
                             'total_docks_start' : 'total_docks_end'},
                               inplace=True)  # This renames the columns 
                                            # so as to merge data with end stations capacities

# %%
data =data.merge(stations_df)

# %% [markdown]
# ### <font color='red'>3.7) Show a sample of data with start and end stations capacities</font>

# %%
data.sample(2)
# Out:
#         tripduration           starttime            stoptime  \
# 67604           1144 2015-06-12 22:49:00 2015-06-12 23:08:00
# 428437          1258 2015-06-08 08:48:00 2015-06-08 09:09:00
#
#         start station id start station name  start station latitude  \
# 67604                428     E 3 St & 1 Ave               40.724677
# 428437               514   12 Ave & W 40 St               40.760875
#
#         start station longitude  end station id      end station name  \
# 67604                -73.987834             351  Front St & Maiden Ln
# 428437               -74.002777             363        West Thames St
#
#         end station latitude  end station longitude  bikeid    usertype  \
# 67604              40.705310             -74.006126   20086  Subscriber
# 428437             40.708347             -74.017134   18539  Subscriber
#
#         birth year  gender  Precipitationmm     Conditions  TemperatureC  \
# 67604       1997.0       1              0.0  Partly Cloudy          28.3
# 428437      1967.0       2              0.0       Overcast          17.8
#
#         total_docks_start  total_docks_end
# 67604                  31               39
# 428437                 53               49

# %% [markdown]
# ### Fill NaN values

# %% [markdown]
# ### <font color='red'>3.8) Print the median dock size using for instance <i>numpy</i></font>

# %%
median_dock_size = np.median(total_docks.values())
print median_dock_size
# Out:
# 30.0

# %% [markdown]
# ### <font color='red'>3.9) What does the following block do ?</font>

# %%
data.total_docks_start.fillna(median_dock_size,inplace = True)
data.total_docks_end.fillna(median_dock_size,inplace = True)

# %% [markdown]
# ### <font color='red'>3.10) Check that there are no NaN dock capacities anymore in <i>data</i></font>

# %%
data.isnull().any()
# Out:
# tripduration               False
# starttime                  False
# stoptime                   False
# start station id           False
# start station name         False
# start station latitude     False
# start station longitude    False
# end station id             False
# end station name           False
# end station latitude       False
# end station longitude      False
# bikeid                     False
# usertype                   False
# birth year                 False
# gender                     False
# Precipitationmm            False
# Conditions                 False
# TemperatureC               False
# total_docks_start          False
# total_docks_end            False
# dtype: bool

# %% [markdown]
# # Dataset we will be working on

# %%
data.sample(2)
# Out:
#         tripduration           starttime            stoptime  \
# 531807           116 2015-06-21 07:49:00 2015-06-21 07:51:00
# 662066           395 2015-06-24 15:30:00 2015-06-24 15:37:00
#
#         start station id          start station name  start station latitude  \
# 531807               453             W 22 St & 8 Ave               40.744751
# 662066              3002  South End Ave & Liberty St               40.711512
#
#         start station longitude  end station id         end station name  \
# 531807               -73.999154             462         W 22 St & 10 Ave
# 662066               -74.015756             249  Harrison St & Hudson St
#
#         end station latitude  end station longitude  bikeid    usertype  \
# 531807              40.74692             -74.004519   15573  Subscriber
# 662066              40.71871             -74.009001   19580  Subscriber
#
#         birth year  gender  Precipitationmm  Conditions  TemperatureC  \
# 531807      1988.0       1             0.03  Light Rain          22.2
# 662066      1987.0       1             0.00       Clear          27.2
#
#         total_docks_start  total_docks_end
# 531807                 39               47
# 662066                 25               27

# %% [markdown]
# # Save dataset to csv file

# %%
data.to_csv('./my_data_after_collection.csv', index=False)

# %% [markdown]
# # Implement your own ideas for data enrichment !

# %%
## Use your imagination to enrich this dataset ##

# %%
len(data)
# Out:
# 797219
